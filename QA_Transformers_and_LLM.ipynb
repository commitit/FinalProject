# %% [markdown]
# <a href="https://colab.research.google.com/github/commitit/FinalProject/blob/main/QA_Transformers_and_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Final Project:
# Elevating Customer Service in Banking with Question Classification Using BERT Model and an LLM-Based Agent

# %% [markdown]
# # Install Libraries

# %%
import transformers
from transformers import DistilBertTokenizer
from transformers import TFDistilBertForSequenceClassification
from transformers import TextClassificationPipeline

import tensorflow as tf
import pandas as pd
import numpy as np
import json
import gc

from sklearn.model_selection import train_test_split

import textwrap
import re
import nltk

#Removing stopwords
# !pip install nltk
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')

import seaborn as sns
import matplotlib.pyplot as plt
from plotly.offline import iplot
from wordcloud import WordCloud
from collections import Counter

from tqdm import tqdm
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Get Data

# %%
#Read CSV from our Github repository
path_to_csv = 'https://raw.githubusercontent.com/commitit/FinalProject/main/BankFAQ.csv'

# %%
df = pd.read_csv(path_to_csv)
df.head(15)
# Out:
#                                              Question  \
# 0   Can I use a personal loan to finance a vacatio...
# 1   What is the process for applying for a student...
# 2                What insurance products do you offer
# 3        How do I apply for insurance through GS Bank
# 4         What types of loans do you offer at GS Bank
# 5                How do I apply for a loan at GS Bank
# 6   What are the eligibility criteria for obtainin...
# 7               Can I use my Debit Card to pay online
# 8    What should I do if my Debit Card is not working
# 9   How do I request a replacement credit card if ...
# 10  What are the benefits of using a credit card f...
# 11            How is my loan interest rate determined
# 12        Can I get a loan with bad credit at GS Bank
# 13  What documents do I need to provide when apply...
# 14   How long does it take to get approved for a loan
#
#                                                Answer      Class
# 0   Yes you can use a personal loan to finance a v...      loans
# 1   The process for applying for a student loan th...      loans
# 2   At GS Bank we offer a range of insurance produ...  insurance
# 3   You can apply for insurance through GS Bank by...  insurance
# 4   GS Bank offers a comprehensive range of loan p...      loans
# 5   Applying for a loan with GS Bank is a straight...      loans
# 6   The eligibility requirements for obtaining a l...      loans
# 7   Currently your Debit Card can be used to make ...      cards
# 8   If there is a technical problem because of whi...      cards
# 9   You can request a replacement credit card by c...      cards
# 10  Using a credit card for everyday purchases off...      cards
# 11  Your loan interest rate is determined based on...      loans
# 12  While having bad credit may impact your loan e...      loans
# 13  When applying for a loan you may need to provi...      loans
# 14  The time to get approved for a loan varies dep...      loans

# %% [markdown]
# ##Data exploration, visualisation and statistics

# %%
df.shape
# Out:
# (2000, 3)

# %%
# checking null values and datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Question  2000 non-null   object
#  1   Answer    2000 non-null   object
#  2   Class     2000 non-null   object
# dtypes: object(3)
# memory usage: 47.0+ KB

# %%
df.head()
# Out:
#                                             Question  \
# 0  Can I use a personal loan to finance a vacatio...
# 1  What is the process for applying for a student...
# 2               What insurance products do you offer
# 3       How do I apply for insurance through GS Bank
# 4        What types of loans do you offer at GS Bank
#
#                                               Answer      Class
# 0  Yes you can use a personal loan to finance a v...      loans
# 1  The process for applying for a student loan th...      loans
# 2  At GS Bank we offer a range of insurance produ...  insurance
# 3  You can apply for insurance through GS Bank by...  insurance
# 4  GS Bank offers a comprehensive range of loan p...      loans

# %% [markdown]
# Check few rows of data

# %%
for i in range(5):
   print(textwrap.fill(df['Question'][i], 150))
   print('Answer :', textwrap.fill(df['Answer'][i], 150))
   print('Class :', df['Class'][i])
   print('')
# Out:
# Can I use a personal loan to finance a vacation or travel expenses
# Answer : Yes you can use a personal loan to finance a vacation or travel expenses providing flexibility and convenience for funding leisure activities trips or
# vacations. Personal loans offer fixed-rate financing with predictable monthly payments allowing you to budget and plan for travel expenses without
# relying on credit cards or depleting savings. Consider factors such as loan amount interest rate and repayment terms when using a personal loan for
# travel purposes and ensure affordability and responsible borrowing practices.
# Class : loans
#
# What is the process for applying for a student loan through GS Bank
# Answer : The process for applying for a student loan through GS Bank involves several steps including completing the Free Application for Federal Student Aid
# (FAFSA) reviewing available loan options submitting a loan application providing required documentation and obtaining loan approval. Our student loan
# specialists will guide you through each stage of the application process assist with FAFSA completion and help you explore federal and private student
# loan options to finance your education affordably.
# Class : loans
#
# What insurance products do you offer
# Answer : At GS Bank we offer a range of insurance products tailored to meet various needs including life insurance health insurance home insurance auto
# insurance and specialty insurance such as travel insurance and pet insurance.
# Class : insurance
#
# How do I apply for insurance through GS Bank
# Answer : You can apply for insurance through GS Bank by contacting our insurance department directly or visiting one of our branch locations. Our insurance
# specialists will guide you through the application process assess your insurance needs and provide personalized recommendations.
# Class : insurance
#
# What types of loans do you offer at GS Bank
# Answer : GS Bank offers a comprehensive range of loan products to meet the diverse needs of our clients. These include personal loans home loans auto loans
# student loans and business loans. Personal loans are unsecured loans that can be used for various purposes such as debt consolidation medical expenses
# or home improvement. Home loans are available for purchasing a new home refinancing an existing mortgage or tapping into your home’s equity through a
# home equity loan or line of credit. Auto loans can help you finance the purchase of a new or used vehicle. Student loans provide financial support for
# educational expenses and business loans cater to the financing needs of small and medium-sized enterprises. Our loan specialists can assist you in
# selecting the right loan product based on your financial situation and goals
# Class : loans

# %%
category_count = df["Class"].value_counts()

# %%
category_count
# Out:
# Class
# loans        500
# insurance    500
# cards        500
# accounts     500
# Name: count, dtype: int64

# %%
categories = category_count.index

categories
# Out:
# Index(['loans', 'insurance', 'cards', 'accounts'], dtype='object', name='Class')

# %%
df['Class'].unique()
# Out:
# array(['loans', 'insurance', 'cards', 'accounts'], dtype=object)

# %% [markdown]
# ###Category distribution plot

# %%
fig = plt.figure(figsize= (10, 8))

ax = fig.add_subplot(111)

sns.barplot(x = category_count.index, y = category_count)

# Define a list of colors
colors = ['#56B4E9', '#55a868', '#D55E00', '#0072B2']

# Set colors for each bar
for patch, color in zip(ax.patches, colors):
    patch.set_facecolor(color)

for a, p in enumerate(ax.patches):
    ax.annotate(f'{categories[a]}\n' + format(p.get_height(), '.0f'), xy = (p.get_x() + p.get_width() / 2.0, p.get_height()), xytext = (0,-25), size = 13, color = 'white' , ha = 'center', va = 'center', textcoords = 'offset points', bbox = dict(boxstyle = 'round', facecolor='none',edgecolor='none', alpha = 0.5) )

plt.xlabel('Class', size = 15)

plt.ylabel('Number of questions', size= 15)

plt.xticks(size = 12)

plt.title("Category distribution" , size = 18)

plt.show()

# %% [markdown]
# ###Check for word count statistics

# %%
#Create a new column 'word_count' with the total number of words in each corresponding question
df['word_count'] = df['Question'].apply(lambda x: len(x.split()))

# %%
df.head(10)
# Out:
#                                             Question  \
# 0  Can I use a personal loan to finance a vacatio...
# 1  What is the process for applying for a student...
# 2               What insurance products do you offer
# 3       How do I apply for insurance through GS Bank
# 4        What types of loans do you offer at GS Bank
# 5               How do I apply for a loan at GS Bank
# 6  What are the eligibility criteria for obtainin...
# 7              Can I use my Debit Card to pay online
# 8   What should I do if my Debit Card is not working
# 9  How do I request a replacement credit card if ...
#
#                                               Answer      Class  word_count
# 0  Yes you can use a personal loan to finance a v...      loans          13
# 1  The process for applying for a student loan th...      loans          13
# 2  At GS Bank we offer a range of insurance produ...  insurance           6
# 3  You can apply for insurance through GS Bank by...  insurance           9
# 4  GS Bank offers a comprehensive range of loan p...      loans          10
# 5  Applying for a loan with GS Bank is a straight...      loans          10
# 6  The eligibility requirements for obtaining a l...      loans           9
# 7  Currently your Debit Card can be used to make ...      cards           9
# 8  If there is a technical problem because of whi...      cards          11
# 9  You can request a replacement credit card by c...      cards          14

# %%
df['word_count'].describe()
# Out:
# count    2000.000000
# mean       11.145000
# std         4.649816
# min         3.000000
# 25%         8.000000
# 50%        11.000000
# 75%        14.000000
# max        34.000000
# Name: word_count, dtype: float64

# %% [markdown]
# Histogram of the count of words in the question column

# %%
mean_word_count = df['word_count'].mean()
median_word_count = df['word_count'].median()
percentile_95 = df['word_count'].quantile(0.95)
percentile_99 = df['word_count'].quantile(0.99)

# Plot histogram
plt.figure(figsize= (10, 6))
plt.hist(df['word_count'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of Word Counts')
plt.xlabel('word_count')
plt.ylabel('Frequency')
plt.axvline(mean_word_count, color='r', linestyle='dashed', linewidth=1, label=f'Mean: {mean_word_count:.2f}')
plt.axvline(median_word_count, color='g', linestyle='dashed', linewidth=1, label=f'Median: {median_word_count:.2f}')
plt.axvline(percentile_95, color='b', linestyle='dashed', linewidth=1, label=f'95th Percentile: {percentile_95:.2f}')
plt.axvline(percentile_99, color='y', linestyle='dashed', linewidth=1, label=f'99th Percentile: {percentile_99:.2f}')
plt.legend()
plt.show()

# %% [markdown]
# Violin plot from Seaborn to show the distribution of words per class

# %%
#Violinplot to show the distribution of words per class
figsize = (10, 1* len(df['Class'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df, x='word_count', y='Class', inner='box', palette='Dark2', hue = 'Class')
sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# Histogram to count the number of characters in each question

# %%
# Adding a column to calculate the number of characters of each question, including letters, numbers, punctuation and spaces
df['Question_Length'] = df['Question'].apply(len)

# Plot the distribution of question lengths
plt.figure(figsize=(8, 6))
sns.histplot(df['Question_Length'], bins=30, kde=True)
plt.title('Distribution of Question Lengths')
plt.xlabel('Question Length')
plt.ylabel('Frequency')
plt.show()

# %%
df['Question_Length'].describe()
# Out:
# count    2000.000000
# mean       59.443500
# std        25.570564
# min        10.000000
# 25%        42.000000
# 50%        56.000000
# 75%        74.000000
# max       187.000000
# Name: Question_Length, dtype: float64

# %% [markdown]
# The average length of the questions are 59, the length of the shortest is 10 characters and the maximum length is 187 characters as shown in our plot.

# %% [markdown]
# ###Word Cloud
# * Provides visual representation of the most common words in the questions.

# %%
# Concatenating all questions into a single string
text = " ".join(question for question in df.Question)

# Creating and generating a word cloud image
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)

# Display the generated image
plt.figure(figsize=(10, 6))  # Optional: adjust the size of the figure
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ###Highlighting the words that frequently appear in the questions.

# %%
# Tokenize words and create a counter
all_words = " ".join(question for question in df.Question).split()
word_freq = Counter(all_words)
common_words = word_freq.most_common(20)

# Create DataFrame for the most common words
common_words_df = pd.DataFrame(common_words, columns=['Word', 'Frequency'])

# Plot the most common words
plt.figure(figsize=(10, 6))
sns.barplot(x='Frequency', y='Word', data=common_words_df)
plt.title('Most Common Words in Questions')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.show()

# %% [markdown]
# We see above that stop words appear the most frequently

# %% [markdown]
# ##Text preprocessing
#
#
# *   HTML Tag Removal
# *   Lowercasing: coverting the reviews to lower case
# *   Remove special characters, punctuation, urls
# *   Removing Stopwords: remove stopwords (common words like "the," "is," "and")

# %%
# function to remove HTML tags
def remove_html_tags(text):
    pattern = re.compile('<.*?>')  # takes a text input and uses a regular expression pattern to remove HTML tags from it.
    return pattern.sub(r'', text)  # Remove HTML tags by an empty string

# Apply the remove_html_tags function to the 'review' column
df['Question'] = df['Question'].apply(remove_html_tags)

# %%
#Converting data into lowercase since python is case sensitive
df['Question']=df['Question'].str.lower()

# %%
#removing URLs from text using regular expression pattern to match URLs starting with "http://" or "https://" as well as URLs starting with "www."
def remove_url(text):
    pattern = re.compile(r'https?://\S+ | www\. \S+')
    return pattern.sub(r'', text)

df['Question'] = df['Question'].apply(remove_url)

# %%
#define function to remove punctuations
def remove_punctuation(text):
    # everything which is not a word (\w) or space (\s) -> empty string ('')
    return re.sub(r'[^\w\s]', '', text)

# Apply the remove_punctuation function to the 'review' column
df['Question'] = df['Question'].apply(remove_punctuation)


df['Question'][0]
# Out:
# 'can i use a personal loan to finance a vacation or travel expenses'

# %%
# Get the English stop words set from NLTK
stop_words = set(stopwords.words('english'))

# Function to remove stop words
def remove_stopwords(text):
    words = text.split()
    # Remove stop words
    filtered_words = [word for word in words if word.lower() not in stop_words]
    # Join the filtered words back into a single string
    return ' '.join(filtered_words)

# Apply the remove_stopwords function to the 'review' column
df['Question'] = df['Question'].apply(remove_stopwords)

# %% [markdown]
# Recheck the most common words after text preprocessing

# %%
# Tokenize words and create a counter
all_words = " ".join(question for question in df.Question).split()
word_freq = Counter(all_words)
common_words = word_freq.most_common(20)

# Create DataFrame for the most common words
common_words_df = pd.DataFrame(common_words, columns=['Word', 'Frequency'])

# Plot the most common words
plt.figure(figsize=(10, 6))
sns.barplot(x='Frequency', y='Word', data=common_words_df)
plt.title('Most Common Words in Questions')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.show()

# %%
for i in range(10):
   print(textwrap.fill(df['Question'][i], 150))
   print('Class :', df['Class'][i])
   print('')
# Out:
# use personal loan finance vacation travel expenses
# Class : loans
#
# process applying student loan gs bank
# Class : loans
#
# insurance products offer
# Class : insurance
#
# apply insurance gs bank
# Class : insurance
#
# types loans offer gs bank
# Class : loans
#
# apply loan gs bank
# Class : loans
#
# eligibility criteria obtaining loan
# Class : loans
#
# use debit card pay online
# Class : cards
#
# debit card working
# Class : cards
#
# request replacement credit card mine damaged expired
# Class : cards

# %% [markdown]
# ##Data preparation & splitting

# %% [markdown]
# ###Encoding the categories to numerical representations
#
#
# *   0 = accounts
# *   1 = cards
# *   2 = insurance
# *   3 = loans

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Encode the 'Class' column
df['category'] = label_encoder.fit_transform(df['Class'])
df.head(23)
# Out:
#                                              Question  \
# 0   use personal loan finance vacation travel expe...
# 1               process applying student loan gs bank
# 2                            insurance products offer
# 3                             apply insurance gs bank
# 4                           types loans offer gs bank
# 5                                  apply loan gs bank
# 6                 eligibility criteria obtaining loan
# 7                           use debit card pay online
# 8                                  debit card working
# 9   request replacement credit card mine damaged e...
# 10      benefits using credit card everyday purchases
# 11                      loan interest rate determined
# 12                        get loan bad credit gs bank
# 13               documents need provide applying loan
# 14                        long take get approved loan
# 15  schedule appointment discuss insurance needs s...
# 16         factors consider purchasing life insurance
# 17  difference term life insurance whole life insu...
# 18           apply loan selfemployed irregular income
# 19             fees associated obtaining loan gs bank
# 20           make changes loan application submission
# 21            interest rates offered savings accounts
# 22          open joint savings account another person
#
#                                                Answer      Class  word_count  \
# 0   Yes you can use a personal loan to finance a v...      loans          13
# 1   The process for applying for a student loan th...      loans          13
# 2   At GS Bank we offer a range of insurance produ...  insurance           6
# 3   You can apply for insurance through GS Bank by...  insurance           9
# 4   GS Bank offers a comprehensive range of loan p...      loans          10
# 5   Applying for a loan with GS Bank is a straight...      loans          10
# 6   The eligibility requirements for obtaining a l...      loans           9
# 7   Currently your Debit Card can be used to make ...      cards           9
# 8   If there is a technical problem because of whi...      cards          11
# 9   You can request a replacement credit card by c...      cards          14
# 10  Using a credit card for everyday purchases off...      cards          12
# 11  Your loan interest rate is determined based on...      loans           7
# 12  While having bad credit may impact your loan e...      loans          11
# 13  When applying for a loan you may need to provi...      loans          12
# 14  The time to get approved for a loan varies dep...      loans          11
# 15  Yes you can schedule an appointment to discuss...  insurance          13
# 16  When purchasing life insurance consider factor...  insurance           9
# 17  Term life insurance provides coverage for a sp...  insurance          12
# 18  Yes you can apply for a loan if you are self-e...      loans          14
# 19  Yes there may be fees associated with obtainin...      loans          12
# 20  In some cases you may be able to make changes ...      loans          10
# 21  Our savings accounts offer competitive interes...   accounts          10
# 22  Yes you can open a joint savings account with ...   accounts          10
#
#     Question_Length  category
# 0                66         3
# 1                67         3
# 2                36         2
# 3                44         2
# 4                43         3
# 5                36         3
# 6                54         3
# 7                37         1
# 8                48         1
# 9                72         1
# 10               67         1
# 11               39         3
# 12               43         3
# 13               60         3
# 14               48         3
# 15               77         2
# 16               61         2
# 17               75         2
# 18               69         3
# 19               64         3
# 20               58         3
# 21               60         0
# 22               54         0

# %% [markdown]
# ###Remove unused columns from the dataset

# %%
df = df.drop(['Answer', 'Class', 'word_count','Question_Length'], axis=1)

# %%
df.head()
# Out:
#                                             Question  category
# 0  use personal loan finance vacation travel expe...         3
# 1              process applying student loan gs bank         3
# 2                           insurance products offer         2
# 3                            apply insurance gs bank         2
# 4                          types loans offer gs bank         3

# %% [markdown]
# ###Data Shuffling
# Shuffling the dataset to ensure randomization and setting random state 42 to get the same shuffled order.

# %%
# Shuffling the dataset to ensure randomization
df = df.sample(frac=1, random_state=42)

# %%
# Printing the last 20 records of the shuffled DataFrame
print(df.tail(20))
# Out:
#                                                Question  category
# 130   dont account gs bank still avail preowned car ...         3
# 1687                             transactions card used         1
# 871              know home insurance policy due renewal         2
# 1123  many critical illnesses covered 3d life 3d lif...         2
# 1396            womans advantage debit card lost stolen         1
# 87    obtain noc bank fitting lpgcng kit vehicle fin...         3
# 1482                                           get card         1
# 330                            repay professionals loan         3
# 1238                  minimum transaction amount scheme         0
# 466   necessary open apex current account location c...         0
# 121                   tenure options preowned car loans         3
# 1638             charges towards availing gcas services         1
# 1044                             surrender benefit plan         2
# 1724                             regalia forexplus card         1
# 1095                                  would go medicals         2
# 1130       difference life life long protection options         2
# 1294              taxes applicable mudra pure gold bars         0
# 860                         cover family members policy         2
# 1459  need pay additional amount cash withdrawal cha...         1
# 1126                   many plan options available plan         2

# %% [markdown]
# ###Split the data set in training and text
# We decided to split the data into 80% training and 20% test data.

# %%
train_texts = df.iloc[:1600]['Question'].values
train_labels = df.iloc[:1600]['category'].values

test_texts = df.iloc[-400:]['Question'].values
test_labels = df.iloc[-400:]['category'].values

# %%
print("Shape of trainset: ", train_texts.shape)
print("Shape pf testset: ", test_texts.shape)
# Out:
# Shape of trainset:  (1600,)
# Shape pf testset:  (400,)

# %%
train_labels.shape
# Out:
# (1600,)

# %% [markdown]
# #Modelling Question Classification

# %% [markdown]
# Install libraries

# %%
import torch
import torch.nn as nn
from transformers import DistilBertForSequenceClassification, DistilBertTokenizerFast
from transformers import RobertaTokenizer, RobertaForSequenceClassification
from transformers import AlbertTokenizer, AlbertForSequenceClassification
from torch.utils.data import DataLoader, Dataset
from transformers import AdamW
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader, Dataset

from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# ##DistilBERT
# DistilBERT is a small, fast, computationally cheap and light Transformer model trained by distilling BERT base. It has 40% less parameters than google-bert/bert-base-uncased, runs 60% faster while preserving over 95% of BERT’s performances as measured on the GLUE language understanding benchmark.

# %% [markdown]
# ###DistilBertForSequenceClassification

# %%
tokenizer = DistilBertTokenizerFast.from_pretrained('distilbert-base-uncased')

# Tokenize the question
train_encodings = tokenizer(list(train_texts), truncation=True, padding=True)
test_encodings = tokenizer(list(test_texts), truncation=True, padding=True)

train_encodings[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
#
#
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning:
#
# `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Encoding(num_tokens=21, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])

# %%
#already encoded before
# Encode labels to integers
#label_encoder = LabelEncoder()
#train_labels = label_encoder.fit_transform(train_labels)
#test_labels = label_encoder.transform(test_labels)

# %%
# Print shapes of labels for debugging
print(f"Train labels shape: {train_labels.shape}")
print(f"Test labels shape: {test_labels.shape}")
# Out:
# Train labels shape: (1600,)
# Test labels shape: (400,)

# %%
class FAQDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx], dtype=torch.long)
        return item

    def __len__(self):
        return len(self.labels)


train_dataset = FAQDataset(train_encodings, train_labels)
test_dataset = FAQDataset(test_encodings, test_labels)

# %%
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False)

# %% [markdown]
# ###Train Model

# %%
# Model and training settings
model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=len(label_encoder.classes_))
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(DEVICE)

optim = torch.optim.Adam(model.parameters(), lr=5e-5)
# Out:
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def compute_accuracy(model, data_loader, device):
    model.eval()
    correct_pred, num_examples = 0, 0

    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            _, predicted_labels = torch.max(outputs.logits, 1)
            num_examples += labels.size(0)
            correct_pred += (predicted_labels == labels).sum().item()

    return correct_pred / num_examples * 100

# %%
#General settings

torch.backends.cudnn.deterministic = True
RANDOM_SEED = 123
torch.manual_seed(RANDOM_SEED)

# %%
NUM_EPOCHS = 20

for epoch in range(NUM_EPOCHS):
    model.train()

    for batch_idx, batch in enumerate(train_loader):
        input_ids = batch['input_ids'].to(DEVICE)
        attention_mask = batch['attention_mask'].to(DEVICE)
        labels = batch['labels'].to(DEVICE)

        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss

        optim.zero_grad()
        loss.backward()
        optim.step()

        if batch_idx % 250 == 0:
            print(f'Epoch: {epoch+1}/{NUM_EPOCHS} | Batch {batch_idx}/{len(train_loader)} | Loss: {loss:.4f}')

    train_acc = compute_accuracy(model, train_loader, DEVICE)
    test_acc = compute_accuracy(model, test_loader, DEVICE)
    print(f'Epoch {epoch+1}/{NUM_EPOCHS} - Training Accuracy: {train_acc:.2f}% | Test Accuracy: {test_acc:.2f}%')

test_acc = compute_accuracy(model, test_loader, DEVICE)
# Out:
# Epoch: 1/20 | Batch 0/400 | Loss: 1.2997
# Epoch: 1/20 | Batch 250/400 | Loss: 0.1365
# Epoch 1/20 - Training Accuracy: 96.38% | Test Accuracy: 93.00%
# Epoch: 2/20 | Batch 0/400 | Loss: 0.0709
# Epoch: 2/20 | Batch 250/400 | Loss: 0.0517
# Epoch 2/20 - Training Accuracy: 96.38% | Test Accuracy: 91.25%
# Epoch: 3/20 | Batch 0/400 | Loss: 0.0075
# Epoch: 3/20 | Batch 250/400 | Loss: 0.0137
# Epoch 3/20 - Training Accuracy: 99.25% | Test Accuracy: 94.50%
# Epoch: 4/20 | Batch 0/400 | Loss: 0.0125
# Epoch: 4/20 | Batch 250/400 | Loss: 0.0049
# Epoch 4/20 - Training Accuracy: 98.81% | Test Accuracy: 93.00%
# Epoch: 5/20 | Batch 0/400 | Loss: 0.0274
# Epoch: 5/20 | Batch 250/400 | Loss: 0.0072
# Epoch 5/20 - Training Accuracy: 99.69% | Test Accuracy: 94.00%
# Epoch: 6/20 | Batch 0/400 | Loss: 0.0028
# Epoch: 6/20 | Batch 250/400 | Loss: 0.0024
# Epoch 6/20 - Training Accuracy: 99.31% | Test Accuracy: 93.50%
# Epoch: 7/20 | Batch 0/400 | Loss: 0.0298
# Epoch: 7/20 | Batch 250/400 | Loss: 0.0010
# Epoch 7/20 - Training Accuracy: 99.88% | Test Accuracy: 94.50%
# Epoch: 8/20 | Batch 0/400 | Loss: 0.0076
# Epoch: 8/20 | Batch 250/400 | Loss: 0.7585
# Epoch 8/20 - Training Accuracy: 99.94% | Test Accuracy: 93.25%
# Epoch: 9/20 | Batch 0/400 | Loss: 0.0022
# Epoch: 9/20 | Batch 250/400 | Loss: 0.0021
# Epoch 9/20 - Training Accuracy: 99.94% | Test Accuracy: 93.75%
# Epoch: 10/20 | Batch 0/400 | Loss: 0.0013
# Epoch: 10/20 | Batch 250/400 | Loss: 0.0004
# Epoch 10/20 - Training Accuracy: 100.00% | Test Accuracy: 94.25%
# Epoch: 11/20 | Batch 0/400 | Loss: 0.0003
# Epoch: 11/20 | Batch 250/400 | Loss: 0.0002
# Epoch 11/20 - Training Accuracy: 100.00% | Test Accuracy: 94.75%
# Epoch: 12/20 | Batch 0/400 | Loss: 0.0002
# Epoch: 12/20 | Batch 250/400 | Loss: 0.0004
# Epoch 12/20 - Training Accuracy: 100.00% | Test Accuracy: 94.75%
# Epoch: 13/20 | Batch 0/400 | Loss: 0.0002
# Epoch: 13/20 | Batch 250/400 | Loss: 0.0001
# Epoch 13/20 - Training Accuracy: 96.56% | Test Accuracy: 91.75%
# Epoch: 14/20 | Batch 0/400 | Loss: 1.6443
# Epoch: 14/20 | Batch 250/400 | Loss: 0.0593
# Epoch 14/20 - Training Accuracy: 99.38% | Test Accuracy: 93.00%
# Epoch: 15/20 | Batch 0/400 | Loss: 0.0522
# Epoch: 15/20 | Batch 250/400 | Loss: 0.0349
# Epoch 15/20 - Training Accuracy: 99.38% | Test Accuracy: 93.00%
# Epoch: 16/20 | Batch 0/400 | Loss: 0.0012
# Epoch: 16/20 | Batch 250/400 | Loss: 0.0061
# Epoch 16/20 - Training Accuracy: 99.88% | Test Accuracy: 94.50%
# Epoch: 17/20 | Batch 0/400 | Loss: 0.0013
# Epoch: 17/20 | Batch 250/400 | Loss: 0.0004
# Epoch 17/20 - Training Accuracy: 99.75% | Test Accuracy: 93.75%
# Epoch: 18/20 | Batch 0/400 | Loss: 0.0017
# Epoch: 18/20 | Batch 250/400 | Loss: 0.0024
# Epoch 18/20 - Training Accuracy: 99.75% | Test Accuracy: 94.25%
# Epoch: 19/20 | Batch 0/400 | Loss: 0.0028
# Epoch: 19/20 | Batch 250/400 | Loss: 0.0004
# Epoch 19/20 - Training Accuracy: 100.00% | Test Accuracy: 94.50%
# Epoch: 20/20 | Batch 0/400 | Loss: 0.0004
# Epoch: 20/20 | Batch 250/400 | Loss: 0.0002
# Epoch 20/20 - Training Accuracy: 99.94% | Test Accuracy: 94.50%

# %%
#from google.colab import drive
#drive.mount('/content/gdrive', force_remount=True)

##Save model to path
#path_model = '/content/drive/MyDrive/Data/DistilBERTmodel.pth'
##save model
#torch.save(model.state_dict(), path_model)

# %%
##load save model
#model_DistilBert = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=len(label_encoder.classes_))
#model__DistilBert.load_state_dict(torch.load(path_model))
#model_DistilBert.eval()

# %%
def predict_sentiment(question, model, tokenizer, device):
    tokens = tokenizer.tokenize(question)
    ids = tokenizer.convert_tokens_to_ids(tokens)
    tensor = torch.LongTensor(ids).unsqueeze(dim=0).to(device)
    outputs = model(tensor)
    logits = outputs.logits.squeeze(dim=0)
    probability = torch.softmax(logits, dim=-1)
    predicted_class = torch.argmax(probability, dim=-1).item()
    return predicted_class, probability

# %%
question = "What type of cards do you have?"

predict_sentiment(question, model, tokenizer, DEVICE)
# Out:
# (1,
#  tensor([9.8516e-05, 9.9984e-01, 4.9621e-05, 7.7243e-06], device='cuda:0',
#         grad_fn=<SoftmaxBackward0>))

# %%
question = "How can I apply for a VISA?"

predict_sentiment(question, model, tokenizer, DEVICE)
# Out:
# (1,
#  tensor([0.2149, 0.7679, 0.0092, 0.0080], device='cuda:0',
#         grad_fn=<SoftmaxBackward0>))

# %%
question = "Can I apply for a mortgage when I am 18?"

predict_sentiment(question, model, tokenizer, DEVICE)
# Out:
# (3,
#  tensor([5.2161e-04, 1.9630e-04, 3.0712e-04, 9.9898e-01], device='cuda:0',
#         grad_fn=<SoftmaxBackward0>))

# %%
# Defining class labels
class_labels = ['Account', 'Cards', 'Insurance', 'Loans']

# Defining a function to generate classification report and confusion matrix
def generate_classification_report_confusion_matrix(model, data_loader, device):
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            logits = outputs.logits
            _, predicted_labels = torch.max(logits, 1)

            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted_labels.cpu().numpy())

    class_report = classification_report(y_true, y_pred)
    print("Classification Report:")
    print(class_report)

    conf_matrix = confusion_matrix(y_true, y_pred)
    print("Confusion Matrix:")
    print(conf_matrix)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix - DistilBERT')
    plt.colorbar()

    plt.xticks(range(len(class_labels)), class_labels, rotation=45)
    plt.yticks(range(len(class_labels)), class_labels)

    ax = plt.gca()
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))

    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')


    for i in range(len(class_labels)):
        for j in range(len(class_labels)):
            plt.text(j, i, conf_matrix[i, j], ha='center', va='center', color="white" if i == j else "black" )

    plt.show()

generate_classification_report_confusion_matrix(model, test_loader, DEVICE)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        94
#            1       0.94      0.93      0.94       122
#            2       0.96      0.94      0.95        98
#            3       1.00      0.99      0.99        86
#
#     accuracy                           0.94       400
#    macro avg       0.95      0.95      0.95       400
# weighted avg       0.95      0.94      0.95       400
#
# Confusion Matrix:
# [[ 87   6   1   0]
#  [  6 114   2   0]
#  [  5   1  92   0]
#  [  0   0   1  85]]

# %% [markdown]
# ##RoBERTa

# %% [markdown]
# ###Tokenization: RobertaTokenizer for consistent preprocessing.
# ####Model and Optimizer: Initialize RobertaForSequenceClassification and use AdamW optimizer with a learning rate of 2e-5.

# %%
# Initialize the RoBERTa tokenizer
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')

# Tokenize the questions and convert to tensors
train_encodings = tokenizer(list(train_texts), truncation=True, padding=True)
test_encodings = tokenizer(list(test_texts), truncation=True, padding=True)

# Encode labels to integers
label_encoder = LabelEncoder()
train_labels = label_encoder.fit_transform(train_labels)
test_labels = label_encoder.transform(test_labels)

class FAQDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx], dtype=torch.long)
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = FAQDataset(train_encodings, train_labels)
test_dataset = FAQDataset(test_encodings, test_labels)

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False)

# Model and training settings
model = RobertaForSequenceClassification.from_pretrained('roberta-base', num_labels=len(label_encoder.classes_))
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(DEVICE)

optim = torch.optim.AdamW(model.parameters(), lr=2e-5)

def compute_accuracy(model, data_loader, device):
    model.eval()
    correct_pred, num_examples = 0, 0

    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            _, predicted_labels = torch.max(outputs.logits, 1)
            num_examples += labels.size(0)
            correct_pred += (predicted_labels == labels).sum().item()

    return correct_pred / num_examples * 100

# General settings
torch.backends.cudnn.deterministic = True
RANDOM_SEED = 123
torch.manual_seed(RANDOM_SEED)

NUM_EPOCHS = 20

for epoch in range(NUM_EPOCHS):
    model.train()

    for batch_idx, batch in enumerate(train_loader):
        input_ids = batch['input_ids'].to(DEVICE)
        attention_mask = batch['attention_mask'].to(DEVICE)
        labels = batch['labels'].to(DEVICE)

        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss

        optim.zero_grad()
        loss.backward()
        optim.step()

        if batch_idx % 250 == 0:
            print(f'Epoch: {epoch+1}/{NUM_EPOCHS} | Batch {batch_idx}/{len(train_loader)} | Loss: {loss:.4f}')

    train_acc = compute_accuracy(model, train_loader, DEVICE)
    test_acc = compute_accuracy(model, test_loader, DEVICE)
    print(f'Epoch {epoch+1}/{NUM_EPOCHS} - Training Accuracy: {train_acc:.2f}% | Test Accuracy: {test_acc:.2f}%')

test_acc = compute_accuracy(model, test_loader, DEVICE)
print(f'Test Accuracy: {test_acc:.2f}%')
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning:
#
# `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch: 1/20 | Batch 0/400 | Loss: 1.4835
# Epoch: 1/20 | Batch 250/400 | Loss: 0.4798
# Epoch 1/20 - Training Accuracy: 95.06% | Test Accuracy: 90.25%
# Epoch: 2/20 | Batch 0/400 | Loss: 0.0663
# Epoch: 2/20 | Batch 250/400 | Loss: 1.0905
# Epoch 2/20 - Training Accuracy: 97.56% | Test Accuracy: 92.75%
# Epoch: 3/20 | Batch 0/400 | Loss: 0.0164
# Epoch: 3/20 | Batch 250/400 | Loss: 0.0363
# Epoch 3/20 - Training Accuracy: 98.06% | Test Accuracy: 93.75%
# Epoch: 4/20 | Batch 0/400 | Loss: 0.0963
# Epoch: 4/20 | Batch 250/400 | Loss: 0.0171
# Epoch 4/20 - Training Accuracy: 96.94% | Test Accuracy: 92.00%
# Epoch: 5/20 | Batch 0/400 | Loss: 0.2201
# Epoch: 5/20 | Batch 250/400 | Loss: 0.0097
# Epoch 5/20 - Training Accuracy: 99.25% | Test Accuracy: 93.50%
# Epoch: 6/20 | Batch 0/400 | Loss: 0.0058
# Epoch: 6/20 | Batch 250/400 | Loss: 0.1590
# Epoch 6/20 - Training Accuracy: 99.25% | Test Accuracy: 95.00%
# Epoch: 7/20 | Batch 0/400 | Loss: 0.0034
# Epoch: 7/20 | Batch 250/400 | Loss: 0.0024
# Epoch 7/20 - Training Accuracy: 99.62% | Test Accuracy: 94.75%
# Epoch: 8/20 | Batch 0/400 | Loss: 0.0054
# Epoch: 8/20 | Batch 250/400 | Loss: 1.2507
# Epoch 8/20 - Training Accuracy: 99.50% | Test Accuracy: 95.00%
# Epoch: 9/20 | Batch 0/400 | Loss: 0.0015
# Epoch: 9/20 | Batch 250/400 | Loss: 0.0046
# Epoch 9/20 - Training Accuracy: 99.88% | Test Accuracy: 93.75%
# Epoch: 10/20 | Batch 0/400 | Loss: 0.2508
# Epoch: 10/20 | Batch 250/400 | Loss: 0.0023
# Epoch 10/20 - Training Accuracy: 99.81% | Test Accuracy: 93.00%
# Epoch: 11/20 | Batch 0/400 | Loss: 0.0012
# Epoch: 11/20 | Batch 250/400 | Loss: 0.0171
# Epoch 11/20 - Training Accuracy: 99.25% | Test Accuracy: 93.00%
# Epoch: 12/20 | Batch 0/400 | Loss: 0.0043
# Epoch: 12/20 | Batch 250/400 | Loss: 0.0714
# Epoch 12/20 - Training Accuracy: 99.88% | Test Accuracy: 93.75%
# Epoch: 13/20 | Batch 0/400 | Loss: 0.0014
# Epoch: 13/20 | Batch 250/400 | Loss: 0.0012
# Epoch 13/20 - Training Accuracy: 99.94% | Test Accuracy: 93.50%
# Epoch: 14/20 | Batch 0/400 | Loss: 0.0005
# Epoch: 14/20 | Batch 250/400 | Loss: 0.0711
# Epoch 14/20 - Training Accuracy: 99.44% | Test Accuracy: 93.75%
# Epoch: 15/20 | Batch 0/400 | Loss: 0.0098
# Epoch: 15/20 | Batch 250/400 | Loss: 0.0411
# Epoch 15/20 - Training Accuracy: 99.81% | Test Accuracy: 93.25%
# Epoch: 16/20 | Batch 0/400 | Loss: 0.0014
# Epoch: 16/20 | Batch 250/400 | Loss: 0.0007
# Epoch 16/20 - Training Accuracy: 99.81% | Test Accuracy: 94.00%
# Epoch: 17/20 | Batch 0/400 | Loss: 0.0064
# Epoch: 17/20 | Batch 250/400 | Loss: 0.0014
# Epoch 17/20 - Training Accuracy: 99.94% | Test Accuracy: 94.50%
# Epoch: 18/20 | Batch 0/400 | Loss: 0.0006
# Epoch: 18/20 | Batch 250/400 | Loss: 0.0013
# Epoch 18/20 - Training Accuracy: 99.94% | Test Accuracy: 93.50%
# Epoch: 19/20 | Batch 0/400 | Loss: 0.0034
# Epoch: 19/20 | Batch 250/400 | Loss: 0.0041
# Epoch 19/20 - Training Accuracy: 99.81% | Test Accuracy: 93.25%
# Epoch: 20/20 | Batch 0/400 | Loss: 0.1563
# Epoch: 20/20 | Batch 250/400 | Loss: 0.0012
# Epoch 20/20 - Training Accuracy: 99.69% | Test Accuracy: 93.50%
# Test Accuracy: 93.50%

# %%
# Defining class labels
class_labels = ['Account', 'Cards', 'Insurance', 'Loans']

# Defining a function to generate classification report and confusion matrix
def generate_classification_report_confusion_matrix(model, data_loader, device):
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            logits = outputs.logits
            _, predicted_labels = torch.max(logits, 1)

            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted_labels.cpu().numpy())

    class_report = classification_report(y_true, y_pred)
    print("Classification Report:")
    print(class_report)

    conf_matrix = confusion_matrix(y_true, y_pred)
    print("Confusion Matrix:")
    print(conf_matrix)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix - RoBERTa')
    plt.colorbar()

    plt.xticks(range(len(class_labels)), class_labels, rotation=45)
    plt.yticks(range(len(class_labels)), class_labels)

    ax = plt.gca()
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))

    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')


    for i in range(len(class_labels)):
        for j in range(len(class_labels)):
            plt.text(j, i, conf_matrix[i, j], ha='center', va='center', color="white" if i == j else "black")

    plt.show()

generate_classification_report_confusion_matrix(model, test_loader, DEVICE)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89        94
#            1       0.95      0.92      0.93       122
#            2       0.97      0.94      0.95        98
#            3       0.96      0.99      0.97        86
#
#     accuracy                           0.94       400
#    macro avg       0.93      0.94      0.94       400
# weighted avg       0.94      0.94      0.94       400
#
# Confusion Matrix:
# [[ 85   6   1   2]
#  [  9 112   1   0]
#  [  4   0  92   2]
#  [  0   0   1  85]]

# %% [markdown]
# ##ALBERT

# %% [markdown]
# ###AlbertTokenizer and AlbertForSequenceClassification

# %%
# Initialize the ALBERT tokenizer
tokenizer = AlbertTokenizer.from_pretrained('albert-base-v2')

# Tokenize the questions and convert to tensors
train_encodings = tokenizer(list(train_texts), truncation=True, padding=True)
test_encodings = tokenizer(list(test_texts), truncation=True, padding=True)

# Encode labels to integers
label_encoder = LabelEncoder()
train_labels = label_encoder.fit_transform(train_labels)
test_labels = label_encoder.transform(test_labels)

class FAQDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx], dtype=torch.long)
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = FAQDataset(train_encodings, train_labels)
test_dataset = FAQDataset(test_encodings, test_labels)

train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=4, shuffle=False)

# Model and training settings
model = AlbertForSequenceClassification.from_pretrained('albert-base-v2', num_labels=len(label_encoder.classes_))
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(DEVICE)

optim = torch.optim.AdamW(model.parameters(), lr=2e-5)

def compute_accuracy(model, data_loader, device):
    model.eval()
    correct_pred, num_examples = 0, 0

    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            _, predicted_labels = torch.max(outputs.logits, 1)
            num_examples += labels.size(0)
            correct_pred += (predicted_labels == labels).sum().item()

    return correct_pred / num_examples * 100

# General settings
torch.backends.cudnn.deterministic = True
RANDOM_SEED = 123
torch.manual_seed(RANDOM_SEED)
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/760k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning:
#
# `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/47.4M [00:00<?, ?B/s]
# Some weights of AlbertForSequenceClassification were not initialized from the model checkpoint at albert-base-v2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
NUM_EPOCHS = 20

for epoch in range(NUM_EPOCHS):
    model.train()

    for batch_idx, batch in enumerate(train_loader):
        input_ids = batch['input_ids'].to(DEVICE)
        attention_mask = batch['attention_mask'].to(DEVICE)
        labels = batch['labels'].to(DEVICE)

        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss

        optim.zero_grad()
        loss.backward()
        optim.step()

        if batch_idx % 250 == 0:
            print(f'Epoch: {epoch+1}/{NUM_EPOCHS} | Batch {batch_idx}/{len(train_loader)} | Loss: {loss:.4f}')

    train_acc = compute_accuracy(model, train_loader, DEVICE)
    test_acc = compute_accuracy(model, test_loader, DEVICE)
    print(f'Epoch {epoch+1}/{NUM_EPOCHS} - Training Accuracy: {train_acc:.2f}% | Test Accuracy: {test_acc:.2f}%')

test_acc = compute_accuracy(model, test_loader, DEVICE)
print(f'Test Accuracy: {test_acc:.2f}%')
# Out:
# Epoch: 1/20 | Batch 0/400 | Loss: 1.5411
# Epoch: 1/20 | Batch 250/400 | Loss: 0.5150
# Epoch 1/20 - Training Accuracy: 88.12% | Test Accuracy: 86.00%
# Epoch: 2/20 | Batch 0/400 | Loss: 0.2376
# Epoch: 2/20 | Batch 250/400 | Loss: 0.4053
# Epoch 2/20 - Training Accuracy: 93.94% | Test Accuracy: 91.25%
# Epoch: 3/20 | Batch 0/400 | Loss: 0.0390
# Epoch: 3/20 | Batch 250/400 | Loss: 0.1061
# Epoch 3/20 - Training Accuracy: 96.06% | Test Accuracy: 92.25%
# Epoch: 4/20 | Batch 0/400 | Loss: 0.2951
# Epoch: 4/20 | Batch 250/400 | Loss: 0.0280
# Epoch 4/20 - Training Accuracy: 96.50% | Test Accuracy: 92.75%
# Epoch: 5/20 | Batch 0/400 | Loss: 1.0826
# Epoch: 5/20 | Batch 250/400 | Loss: 0.0164
# Epoch 5/20 - Training Accuracy: 97.56% | Test Accuracy: 93.50%
# Epoch: 6/20 | Batch 0/400 | Loss: 0.0072
# Epoch: 6/20 | Batch 250/400 | Loss: 0.0148
# Epoch 6/20 - Training Accuracy: 98.50% | Test Accuracy: 94.00%
# Epoch: 7/20 | Batch 0/400 | Loss: 0.0034
# Epoch: 7/20 | Batch 250/400 | Loss: 0.0017
# Epoch 7/20 - Training Accuracy: 99.56% | Test Accuracy: 94.25%
# Epoch: 8/20 | Batch 0/400 | Loss: 0.0110
# Epoch: 8/20 | Batch 250/400 | Loss: 0.1839
# Epoch 8/20 - Training Accuracy: 99.62% | Test Accuracy: 95.25%
# Epoch: 9/20 | Batch 0/400 | Loss: 0.0045
# Epoch: 9/20 | Batch 250/400 | Loss: 0.0007
# Epoch 9/20 - Training Accuracy: 97.44% | Test Accuracy: 91.00%
# Epoch: 10/20 | Batch 0/400 | Loss: 0.2468
# Epoch: 10/20 | Batch 250/400 | Loss: 0.0041
# Epoch 10/20 - Training Accuracy: 99.00% | Test Accuracy: 94.25%
# Epoch: 11/20 | Batch 0/400 | Loss: 0.1790
# Epoch: 11/20 | Batch 250/400 | Loss: 0.0031
# Epoch 11/20 - Training Accuracy: 99.06% | Test Accuracy: 95.00%
# Epoch: 12/20 | Batch 0/400 | Loss: 0.0053
# Epoch: 12/20 | Batch 250/400 | Loss: 0.0249
# Epoch 12/20 - Training Accuracy: 98.50% | Test Accuracy: 93.75%
# Epoch: 13/20 | Batch 0/400 | Loss: 0.0167
# Epoch: 13/20 | Batch 250/400 | Loss: 0.0009
# Epoch 13/20 - Training Accuracy: 98.31% | Test Accuracy: 92.75%
# Epoch: 14/20 | Batch 0/400 | Loss: 0.0037
# Epoch: 14/20 | Batch 250/400 | Loss: 0.0007
# Epoch 14/20 - Training Accuracy: 99.06% | Test Accuracy: 93.75%
# Epoch: 15/20 | Batch 0/400 | Loss: 0.0011
# Epoch: 15/20 | Batch 250/400 | Loss: 0.0067
# Epoch 15/20 - Training Accuracy: 99.62% | Test Accuracy: 93.25%
# Epoch: 16/20 | Batch 0/400 | Loss: 0.0006
# Epoch: 16/20 | Batch 250/400 | Loss: 0.0005
# Epoch 16/20 - Training Accuracy: 99.38% | Test Accuracy: 94.00%
# Epoch: 17/20 | Batch 0/400 | Loss: 0.0038
# Epoch: 17/20 | Batch 250/400 | Loss: 0.0009
# Epoch 17/20 - Training Accuracy: 99.38% | Test Accuracy: 94.00%
# Epoch: 18/20 | Batch 0/400 | Loss: 0.0013
# Epoch: 18/20 | Batch 250/400 | Loss: 0.0994
# Epoch 18/20 - Training Accuracy: 99.44% | Test Accuracy: 93.75%
# Epoch: 19/20 | Batch 0/400 | Loss: 0.0058
# Epoch: 19/20 | Batch 250/400 | Loss: 0.0011
# Epoch 19/20 - Training Accuracy: 98.62% | Test Accuracy: 92.25%
# Epoch: 20/20 | Batch 0/400 | Loss: 0.0020
# Epoch: 20/20 | Batch 250/400 | Loss: 0.0021
# Epoch 20/20 - Training Accuracy: 99.25% | Test Accuracy: 92.50%
# Test Accuracy: 92.50%

# %%
# Defining class labels
class_labels = ['Account', 'Cards', 'Insurance', 'Loans']

# Defining a function to generate classification report and confusion matrix
def generate_classification_report_confusion_matrix(model, data_loader, device):
    model.eval()
    y_true = []
    y_pred = []

    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            logits = outputs.logits
            _, predicted_labels = torch.max(logits, 1)

            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted_labels.cpu().numpy())

    class_report = classification_report(y_true, y_pred)
    print("Classification Report:")
    print(class_report)

    conf_matrix = confusion_matrix(y_true, y_pred)
    print("Confusion Matrix:")
    print(conf_matrix)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Confusion Matrix - ALBERT')
    plt.colorbar()

    plt.xticks(range(len(class_labels)), class_labels, rotation=45)
    plt.yticks(range(len(class_labels)), class_labels)

    ax = plt.gca()
    ax.xaxis.set_major_locator(MaxNLocator(integer=True))
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))

    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')


    for i in range(len(class_labels)):
        for j in range(len(class_labels)):
            plt.text(j, i, conf_matrix[i, j], ha='center', va='center', color="white" if i == j else "black")

    plt.show()

generate_classification_report_confusion_matrix(model, test_loader, DEVICE)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89        94
#            1       0.96      0.92      0.94       122
#            2       0.94      0.93      0.93        98
#            3       0.89      0.99      0.93        86
#
#     accuracy                           0.93       400
#    macro avg       0.92      0.93      0.92       400
# weighted avg       0.93      0.93      0.92       400
#
# Confusion Matrix:
# [[ 82   3   5   4]
#  [  6 112   0   4]
#  [  2   2  91   3]
#  [  0   0   1  85]]

# %% [markdown]
# #Building a LLM-based Agent (retrieval-based QA system)

# %% [markdown]
# ##Install Libraries

# %%
pip install langchain python-dotenv streamlit tiktoken faiss-cpu protobuf langchain_community sentence-transformers==2.2.2 InstructorEmbedding gradio google-cloud-aiplatform
# Out:
# Collecting langchain
#   Downloading langchain-0.2.5-py3-none-any.whl (974 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 7.4 MB/s eta 0:00:00
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting streamlit
#   Downloading streamlit-1.36.0-py2.py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 26.7 MB/s eta 0:00:00
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.8 MB/s eta 0:00:00
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 32.4 MB/s eta 0:00:00
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (3.20.3)
# Collecting langchain_community
#   Downloading langchain_community-0.2.5-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 66.1 MB/s eta 0:00:00
# Collecting sentence-transformers==2.2.2
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 12.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting InstructorEmbedding
#   Downloading InstructorEmbedding-1.0.1-py2.py3-none-any.whl (19 kB)
# Collecting gradio
#   Downloading gradio-4.36.1-py3-none-any.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 24.8 MB/s eta 0:00:00
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.10/dist-packages (1.56.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (4.41.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (4.66.4)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (2.3.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (0.18.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers==2.2.2) (0.23.4)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.7 (from langchain)
#   Downloading langchain_core-0.2.9-py3-none-any.whl (321 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 34.9 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.1-py3-none-any.whl (23 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.81-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.1/127.1 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.7.4)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.4.1)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 29.6 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 108.4 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Collecting watchdog<5,>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.1-py3-none-manylinux2014_x86_64.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.5.15)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Collecting fastapi (from gradio)
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 14.6 MB/s eta 0:00:00
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==1.0.1 (from gradio)
#   Downloading gradio_client-1.0.1-py3-none-any.whl (318 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.1/318.1 kB 40.0 MB/s eta 0:00:00
# Collecting httpx>=0.24.1 (from gradio)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (3.7.1)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 23.2 MB/s eta 0:00:00
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.4.10-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 118.0 MB/s eta 0:00:00
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio) (0.12.3)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio) (2.0.7)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.0.1->gradio) (2023.6.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==1.0.1->gradio)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.11.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.23.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.8.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (3.21.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (1.12.3)
# Requirement already satisfied: shapely<3.0.0dev in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (2.0.4)
# Requirement already satisfied: docstring-parser<1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-aiplatform) (0.16)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 8.0 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.63.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.48.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.7.1)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /usr/local/lib/python3.10/dist-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.13.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.15.1)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.7->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.18.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.6.0->sentence-transformers==2.2.2)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.6.0->sentence-transformers==2.2.2)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.6.0->sentence-transformers==2.2.2)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.6.0->sentence-transformers==2.2.2)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.6.0->sentence-transformers==2.2.2)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.6.0->sentence-transformers==2.2.2)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.6.0->sentence-transformers==2.2.2)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.6.0->sentence-transformers==2.2.2)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.6.0->sentence-transformers==2.2.2)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.6.0->sentence-transformers==2.2.2)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.6.0->sentence-transformers==2.2.2)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->sentence-transformers==2.2.2)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 77.5 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.4.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 9.3 MB/s eta 0:00:00
# Collecting fastapi-cli>=0.0.2 (from fastapi->gradio)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi->gradio)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.6 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi->gradio)
#   Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers==2.2.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers==2.2.2) (3.5.0)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->gradio)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 31.7 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.5.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.7->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio) (1.2.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting httptools>=0.5.0 (from uvicorn>=0.14.0->gradio)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 44.4 MB/s eta 0:00:00
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn>=0.14.0->gradio)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 91.5 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn>=0.14.0->gradio)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 86.6 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers==2.2.2) (1.3.0)
# Building wheels for collected packages: sentence-transformers, ffmpy
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125924 sha256=db0d8a5ee89fe72d7f3981a14b3aedab8e846315a407f4a3e12710c048c1cbb1
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=3ec6b841a41e63b2dcf61e6067af840e7d331e76bd9175ade67374c70b69ecaf
#   Stored in directory: /root/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built sentence-transformers ffmpy
# Installing collected packages: pydub, InstructorEmbedding, ffmpy, websockets, watchdog, uvloop, ujson, tomlkit, smmap, semantic-version, ruff, python-multipart, python-dotenv, orjson, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, marshmallow, jsonpointer, httptools, h11, faiss-cpu, dnspython, aiofiles, watchfiles, uvicorn, typing-inspect, tiktoken, starlette, pydeck, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jsonpatch, httpcore, gitdb, email_validator, nvidia-cusolver-cu12, langsmith, httpx, gitpython, dataclasses-json, langchain-core, gradio-client, fastapi-cli, streamlit, langchain-text-splitters, fastapi, sentence-transformers, langchain, gradio, langchain_community
# Successfully installed InstructorEmbedding-1.0.1 aiofiles-23.2.1 dataclasses-json-0.6.7 dnspython-2.6.1 email_validator-2.2.0 faiss-cpu-1.8.0 fastapi-0.111.0 fastapi-cli-0.0.4 ffmpy-0.3.2 gitdb-4.0.11 gitpython-3.1.43 gradio-4.36.1 gradio-client-1.0.1 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.5 langchain-core-0.2.9 langchain-text-splitters-0.2.1 langchain_community-0.2.5 langsmith-0.1.81 marshmallow-3.21.3 mypy-extensions-1.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 orjson-3.10.5 pydeck-0.9.1 pydub-0.25.1 python-dotenv-1.0.1 python-multipart-0.0.9 ruff-0.4.10 semantic-version-2.10.0 sentence-transformers-2.2.2 smmap-5.0.1 starlette-0.37.2 streamlit-1.36.0 tiktoken-0.7.0 tomlkit-0.12.0 typing-inspect-0.9.0 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchdog-4.0.1 watchfiles-0.22.0 websockets-11.0.3

# %%
from langchain.chains import RetrievalQA
from langchain.embeddings import GooglePalmEmbeddings
from langchain.llms import GooglePalm
from langchain.document_loaders.csv_loader import CSVLoader
from InstructorEmbedding import INSTRUCTOR
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceInstructEmbeddings
from langchain.prompts import PromptTemplate
import pandas as pd
from google.cloud import aiplatform
import os

# %% [markdown]
# ##Load Data

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
loader = CSVLoader(file_path="/content/gdrive/MyDrive/DATA/BankFAQLLM.csv", source_column="Question")
data = loader.load()

# %%
for i in loader.lazy_load():
    print(i)
# Out:
# page_content='Question: Can I use a personal loan to finance a vacation or travel expenses\nAnswer: Yes you can use a personal loan to finance a vacation or travel expenses providing flexibility and convenience for funding leisure activities trips or vacations. Personal loans offer fixed-rate financing with predictable monthly payments allowing you to budget and plan for travel expenses without relying on credit cards or depleting savings. Consider factors such as loan amount interest rate and repayment terms when using a personal loan for travel purposes and ensure affordability and responsible borrowing practices.\nClass: loans' metadata={'source': 'Can I use a personal loan to finance a vacation or travel expenses', 'row': 0}
# page_content='Question: What is the process for applying for a student loan through GS Bank\nAnswer: The process for applying for a student loan through GS Bank involves several steps including completing the Free Application for Federal Student Aid (FAFSA) reviewing available loan options submitting a loan application providing required documentation and obtaining loan approval. Our student loan specialists will guide you through each stage of the application process assist with FAFSA completion and help you explore federal and private student loan options to finance your education affordably.\nClass: loans' metadata={'source': 'What is the process for applying for a student loan through GS Bank', 'row': 1}
# page_content='Question: What insurance products do you offer\nAnswer: At GS Bank we offer a range of insurance products tailored to meet various needs including life insurance health insurance home insurance auto insurance and specialty insurance such as travel insurance and pet insurance.\nClass: insurance' metadata={'source': 'What insurance products do you offer', 'row': 2}
# page_content='Question: How do I apply for insurance through GS Bank\nAnswer: You can apply for insurance through GS Bank by contacting our insurance department directly or visiting one of our branch locations. Our insurance specialists will guide you through the application process assess your insurance needs and provide personalized recommendations.\nClass: insurance' metadata={'source': 'How do I apply for insurance through GS Bank', 'row': 3}
# page_content='Question: What types of loans do you offer at GS Bank\nAnswer: GS Bank offers a comprehensive range of loan products to meet the diverse needs of our clients. These include personal loans home loans auto loans student loans and business loans. Personal loans are unsecured loans that can be used for various purposes such as debt consolidation medical expenses or home improvement. Home loans are available for purchasing a new home refinancing an existing mortgage or tapping into your home’s equity through a home equity loan or line of credit. Auto loans can help you finance the purchase of a new or used vehicle. Student loans provide financial support for educational expenses and business loans cater to the financing needs of small and medium-sized enterprises. Our loan specialists can assist you in selecting the right loan product based on your financial situation and goals\nClass: loans' metadata={'source': 'What types of loans do you offer at GS Bank', 'row': 4}
# page_content='Question: How do I apply for a loan at GS Bank\nAnswer: Applying for a loan with GS Bank is a straightforward process. You can start your application online through our secure website visit any of our branches or call our customer service team. The online application allows you to conveniently fill out your personal and financial information and submit any required documentation electronically. If you prefer in-person assistance our branch representatives are available to guide you through the application process. Once your application is submitted it will be reviewed and you will be contacted regarding the next steps which may include additional documentation or verification of information.\nClass: loans' metadata={'source': 'How do I apply for a loan at GS Bank', 'row': 5}
# page_content='Question: What are the eligibility criteria for obtaining a loan\nAnswer: The eligibility requirements for obtaining a loan from GS Bank vary depending on the type of loan you are applying for. Generally we consider factors such as your credit score income employment history and debt-to-income ratio. For personal loans a good credit score and stable income are typically required. Home loans often require a minimum credit score a down payment and proof of stable employment and income. Auto loans may have similar requirements but are usually more lenient if the vehicle itself can serve as collateral. Student loans may depend on your educational institution and enrollment status and business loans often require a comprehensive business plan financial statements and possibly collateral. Our loan officers can provide specific eligibility criteria based on the loan product you are interested in.\nClass: loans' metadata={'source': 'What are the eligibility criteria for obtaining a loan', 'row': 6}
# page_content='Question: Can I use my Debit Card to pay online\nAnswer: Currently your Debit Card can be used to make purchases from online merchants who have the Verified by Visa/ MasterCard SecureCode certification displayed on their web site. Learn more about using your Debit card for making online purchases here.\nClass: cards' metadata={'source': 'Can I use my Debit Card to pay online', 'row': 7}
# page_content='Question: What should I do if my Debit Card is not working\nAnswer: If there is a technical problem because of which your card is not working we request you to contact us on our Phone Banking center or branch and hotlist/block the said card. Please make a request to issue a new card for your account which will be free of cost and should be delivered to you in 7 working days time once issued. For more details on PhoneBanking numbers and their timings click here. For a comprehensive list of branches click here. View more\nClass: cards' metadata={'source': 'What should I do if my Debit Card is not working', 'row': 8}
# page_content="Question: How do I request a replacement credit card if mine is damaged or expired\nAnswer: You can request a replacement credit card by contacting customer service or submitting a request through our online banking portal. We'll issue a new card with a new expiration date and transfer your existing account information to the replacement card.\nClass: cards" metadata={'source': 'How do I request a replacement credit card if mine is damaged or expired', 'row': 9}
# page_content='Question: What are the benefits of using a credit card for everyday purchases\nAnswer: Using a credit card for everyday purchases offers benefits such as convenience purchase protection rewards fraud liability protection building credit history and tracking expenses. Paying with a credit card can also provide additional warranty coverage and dispute resolution assistance for certain purchases.\nClass: cards' metadata={'source': 'What are the benefits of using a credit card for everyday purchases', 'row': 10}
# page_content='Question: How is my loan interest rate determined\nAnswer: Your loan interest rate is determined based on factors such as your creditworthiness loan amount loan term prevailing market rates and lender policies. Applicants with higher credit scores and lower perceived risk may qualify for lower interest rates while borrowers with lower credit scores or higher risk profiles may receive higher interest rates to compensate for increased lending risk.\nClass: loans' metadata={'source': 'How is my loan interest rate determined', 'row': 11}
# page_content='Question: Can I get a loan with bad credit at GS Bank\nAnswer: While having bad credit may impact your loan eligibility and interest rate GS Bank offers loan options tailored to individuals with varying credit profiles. We assess each loan application on a case-by-case basis considering factors beyond credit score and providing personalized solutions to help meet your financial needs. Contact our loan specialists to explore available loan options and discuss potential financing solutions based on your credit situation.\nClass: loans' metadata={'source': 'Can I get a loan with bad credit at GS Bank', 'row': 12}
# page_content="Question: What documents do I need to provide when applying for a loan\nAnswer: When applying for a loan you may need to provide documents such as proof of identity (e.g. driver's license passport) proof of income (e.g. pay stubs tax returns) employment verification bank statements asset verification and any additional documentation requested by the lender. Ensure you have all required documents ready to expedite the loan application process.\nClass: loans" metadata={'source': 'What documents do I need to provide when applying for a loan', 'row': 13}
# page_content='Question: How long does it take to get approved for a loan\nAnswer: The time to get approved for a loan varies depending on factors such as the type of loan application completeness documentation accuracy lender processing time and credit evaluation. Some loans may be approved within hours or days while others may take longer to review and underwrite. Our loan specialists work diligently to process loan applications promptly and keep you informed throughout the approval process.\nClass: loans' metadata={'source': 'How long does it take to get approved for a loan', 'row': 14}
# page_content='Question: Can I schedule an appointment to discuss my insurance needs with a specialist\nAnswer: Yes you can schedule an appointment to discuss your insurance needs with one of our insurance specialists by contacting our insurance department or visiting a branch location. Our knowledgeable specialists will provide expert guidance and personalized recommendations to help you make informed decisions about your insurance coverage.\nClass: insurance' metadata={'source': 'Can I schedule an appointment to discuss my insurance needs with a specialist', 'row': 15}
# page_content='Question: What factors should I consider when purchasing life insurance\nAnswer: When purchasing life insurance consider factors such as your financial obligations income replacement needs outstanding debts future expenses (e.g. mortgage education costs) family dependents health status lifestyle and long-term financial goals. Assessing your insurance needs comprehensively will help determine the appropriate coverage amount and policy type.\nClass: insurance' metadata={'source': 'What factors should I consider when purchasing life insurance', 'row': 16}
# page_content='Question: What is the difference between term life insurance and whole life insurance\nAnswer: Term life insurance provides coverage for a specified period (e.g. 10 20 or 30 years) and pays a death benefit if the insured passes away during the term. Whole life insurance offers coverage for life and includes a cash value component that accumulates over time providing lifelong protection and potential for cash value growth.\nClass: insurance' metadata={'source': 'What is the difference between term life insurance and whole life insurance', 'row': 17}
# page_content='Question: Can I apply for a loan if I am self-employed or have irregular income\nAnswer: Yes you can apply for a loan if you are self-employed or have irregular income although additional documentation and verification may be required to assess your income stability and repayment capacity. Self-employed individuals may need to provide tax returns profit and loss statements bank statements and other financial documents to verify income and qualify for a loan. Our loan specialists understand the unique challenges faced by self-employed borrowers and can assist with specialized loan solutions tailored to your financial situation.\nClass: loans' metadata={'source': 'Can I apply for a loan if I am self-employed or have irregular income', 'row': 18}
# page_content='Question: Are there any fees associated with obtaining a loan from GS Bank\nAnswer: Yes there may be fees associated with obtaining a loan from GS Bank such as origination fees application fees appraisal fees credit report fees and closing costs. The specific fees vary depending on the type of loan loan amount and lender policies. Our loan specialists will provide a transparent breakdown of all applicable fees and closing costs associated with your loan transaction ensuring full disclosure and clarity throughout the lending process.\nClass: loans' metadata={'source': 'Are there any fees associated with obtaining a loan from GS Bank', 'row': 19}
# page_content='Question: Can I make changes to my loan application after submission\nAnswer: In some cases you may be able to make changes to your loan application after submission such as updating personal information correcting errors or providing additional documentation requested by the lender. However significant changes to loan terms or borrower qualifications may require reevaluation of the loan application and potential adjustments to loan terms. Contact our loan department promptly if you need to make changes to your loan application to ensure accuracy and compliance with lender requirements.\nClass: loans' metadata={'source': 'Can I make changes to my loan application after submission', 'row': 20}
# page_content='Question: What are the interest rates offered on your savings accounts\nAnswer: Our savings accounts offer competitive interest rates which are subject to change based on market conditions. Please visit our website or contact customer service for the most up-to-date rates and information.\nClass: accounts' metadata={'source': 'What are the interest rates offered on your savings accounts', 'row': 21}
# page_content='Question: Can I open a joint savings account with another person\nAnswer: Yes you can open a joint savings account with another person such as a spouse or family member by completing a joint account application. Both account holders have equal ownership rights and access to the funds in the account.\nClass: accounts' metadata={'source': 'Can I open a joint savings account with another person', 'row': 22}
# page_content='Question: What is the minimum balance requirement for your savings accounts\nAnswer: Our savings accounts typically have no minimum balance requirements allowing you to open an account with any amount. However maintaining a certain balance may be necessary to qualify for specific account benefits or avoid monthly maintenance fees.\nClass: accounts' metadata={'source': 'What is the minimum balance requirement for your savings accounts', 'row': 23}
# page_content='Question: How do I deposit money into my savings account\nAnswer: You can deposit money into your savings account through various methods including electronic transfers mobile check deposits direct deposits wire transfers and in-person deposits at our branch locations or affiliated ATMs.\nClass: accounts' metadata={'source': 'How do I deposit money into my savings account', 'row': 24}
# page_content='Question: Are my deposits insured by the FDIC\nAnswer: Yes your deposits with GS Bank are insured by the Federal Deposit Insurance Corporation (FDIC) up to the maximum allowable limit per depositor per account ownership category. FDIC insurance provides protection against bank failure and ensures the safety of your funds.\nClass: accounts' metadata={'source': 'Are my deposits insured by the FDIC', 'row': 25}
# page_content='Question: What are the benefits of opening a high-yield savings account\nAnswer: High-yield savings accounts offer competitive interest rates compounded daily to help your savings grow faster over time. They provide liquidity security and easy access to your funds while maximizing your earning potential compared to traditional savings accounts.\nClass: accounts' metadata={'source': 'What are the benefits of opening a high-yield savings account', 'row': 26}
# page_content='Question: Can I link external accounts for easy transfers to and from my savings account\nAnswer: Yes you can link external accounts to your savings account for convenient transfers and transactions. Simply set up external account connections through our online banking platform and initiate transfers as needed.\nClass: accounts' metadata={'source': 'Can I link external accounts for easy transfers to and from my savings account', 'row': 27}
# page_content='Question: What is the process for applying for a mortgage loan\nAnswer: The process for applying for a mortgage loan involves several steps including prequalification loan application submission documentation verification property appraisal underwriting review loan approval and closing. Our mortgage specialists will guide you through each stage of the mortgage application process answer your questions and assist with required paperwork to ensure a smooth and efficient mortgage transaction.\nClass: loans' metadata={'source': 'What is the process for applying for a mortgage loan', 'row': 28}
# page_content="Question: What is Verified by Visa/MasterCard SecureCode\nAnswer: Verified by Visa/ MasterCard SecureCode is a service that lets you use a personal password/ SecureCode with your GS Bank card. This SecureCode gives you added assurance that only you can use your GS Bank Card to make purchases over the Internet. Just turn on your computer connect to the Internet and pull out your GS Bank Card. You don't need any special software. Use Verified by Visa/ MasterCard SecureCode as easily as you use your PIN at an ATM. View more\nClass: cards" metadata={'source': 'What is Verified by Visa/MasterCard SecureCode', 'row': 29}
# page_content='Question: How do I register my GS Bank Card\nAnswer: You can register your GS Bank Card through the GS Bank Website or through any participating online shopping site when prompted for registration.\nClass: cards' metadata={'source': 'How do I register my GS Bank Card', 'row': 30}
# page_content='Question: Can I register for Verified by Visa/MasterCard SecureCode with my existing GS Bank Card or do I need to apply for a new one\nAnswer: Yes you can register with any of your GS Bank Cards to be protected by Verified by Visa/ MasterCard SecureCode. You dont  need to apply for a new GS Bank Card.\nClass: cards' metadata={'source': 'Can I register for Verified by Visa/MasterCard SecureCode with my existing GS Bank Card or do I need to apply for a new one', 'row': 31}
# page_content='Question: Can I register more than one GS Bank Credit/ Debit Card\nAnswer: Yes you can register all of your GS Bank Credit and Debit Cards for Verified by Visa/MasterCard SecureCode.\nClass: cards' metadata={'source': 'Can I register more than one GS Bank Credit/ Debit Card', 'row': 32}
# page_content='Question: If I have just received a renewed card  do I need to re-register\nAnswer: No you do not have to re-register your renewed card since the card number remains the same. You need to re-register only if your card number has changed due to card replacement/ re-issue/ upgrade.\nClass: cards' metadata={'source': 'If I have just received a renewed card  do I need to re-register', 'row': 33}
# page_content='Question: Can I register my non-Visa payment Cards with Verified by Visa and non- MasterCard payment Cards with MasterCard SecureCode\nAnswer: Currently Verified by Visa is only offered to protect Visa Cards and MasterCard SecureCode to protect MasterCard Cards.\nClass: cards' metadata={'source': 'Can I register my non-Visa payment Cards with Verified by Visa and non- MasterCard payment Cards with MasterCard SecureCode', 'row': 34}
# page_content='Question: Can I use Verified by Visa/ MasterCard SecureCode from any other computer\nAnswer: Yes you can use Verified by Visa/ MasterCard SecureCode from any computer that has an Internet connection and Internet Explorer 5.0 and above or Mozilla Firefox 1.5 and above or Netscape Navigator 8.1 and above.\nClass: cards' metadata={'source': 'Can I use Verified by Visa/ MasterCard SecureCode from any other computer', 'row': 35}
# page_content='Question: Do I need any special equipment or software on my computer\nAnswer: No. All you need is an Internet connection and Internet Explorer 5.0 and above or Mozilla Firefox 1.5 and above or Netscape Navigator 8.1 and above. Find out if you browser is compatible by going to the Help menu on the upper right-hand side of your browser and select the About option. It will tell you what version is installed on your computer.\nClass: cards' metadata={'source': 'Do I need any special equipment or software on my computer', 'row': 36}
# page_content='Question: What is a Personal Assurance Message or Personal Greeting\nAnswer: When you register for Verified by Visa/ MasterCard SecureCode you are asked to create a Personal Assurance Message/ Personal Greeting. So when you pay online always look for your Personal Assurance Message/ Personal Message to ensure that GS Bank is authenticating you. View more\nClass: cards' metadata={'source': 'What is a Personal Assurance Message or Personal Greeting', 'row': 37}
# page_content='Question: How can I register for VBV/SC if my mobile number / Email ID is not updated in my Credit Card records with the Bank\nAnswer: You will have to first have the details updated in our system by calling our Customer Care Centre and attempt to register later. The same will apply if there is a recent change in your mobile number.\nClass: cards' metadata={'source': 'How can I register for VBV/SC if my mobile number / Email ID is not updated in my Credit Card records with the Bank', 'row': 38}
# page_content='Question: How long does it take for the IVR Password  to get delivered using Verified by Visa/Mastercard Secure Code\nAnswer: The IVR Password will get delivered instantly in less than a minute. Please ensure that you also check your Spam Junk and all other folders for the IVR Password mailer from GS Bank.\nClass: cards' metadata={'source': 'How long does it take for the IVR Password  to get delivered using Verified by Visa/Mastercard Secure Code', 'row': 39}
# page_content='Question: If I have registered two email Ids  on which email ID will I receive the IVR Password\nAnswer: If there are 2 email IDs updated in our system IVR Password will be sent to both email IDs. However only one of them is required for validation during registration / password reset.\nClass: cards' metadata={'source': 'If I have registered two email Ids  on which email ID will I receive the IVR Password ', 'row': 40}
# page_content='Question: What is the validity of the IVR Password  using Verified by Visa/Mastercard Secure Code\nAnswer: The IVR Password is valid for 2 hours. If you do not use it within 2 hours of generation of IVR Password  it will expire. You will have to attempt registration again and use the new IVR Password . On expiry of IVR Password generated through the earlier request you can attempt registration again to generate another IVR Password .\nClass: cards' metadata={'source': 'What is the validity of the IVR Password  using Verified by Visa/Mastercard Secure Code', 'row': 41}
# page_content='Question: What are the other things that I need to keep in mind about the IVR Password using Verified by Visa/Mastercard Secure Code\nAnswer: If you have provided 2 email IDs for our records you need to enter any one of them for validation. Also if your email ID and mobile number are not updated please have the details updated in our system by calling our Customer Care Centre and attempt to register later. It is mandatory to have at least one email ID and one mobile number registered. The same will apply if there is a recent change in your mobile number or email ID. View more\nClass: accounts' metadata={'source': 'What are the other things that I need to keep in mind about the IVR Password using Verified by Visa/Mastercard Secure Code', 'row': 42}
# page_content='Question: In what transactions is the One Time Password (IVR Password ) process applicable\nAnswer: The IVR Password process is applicable only for Credit Cards for: Registration through GS Bank website Registration during online shopping Password re-set through website Password re-set while shopping online View more\nClass: cards' metadata={'source': 'In what transactions is the One Time Password (IVR Password ) process applicable', 'row': 43}
# page_content="Question: I don't see my Personal Assurance Message on the Secure page . What should I do\nAnswer: Always look for your Personal Assurance Message before entering your Verified by Visa / MasterCard Securecode password. If your Personal Assurance Message does not appear on the secure page do not enter your password. Please contact our Customer Care Center and update the same.\nClass: accounts" metadata={'source': "I don't see my Personal Assurance Message on the Secure page . What should I do", 'row': 44}
# page_content='Question: If I forget my VBV/MSC  password  how do I retrieve the same\nAnswer: If you have forgotten your password Click on Forgot password on Netsafe login page. Authenticate your identity after entering your Credit/Debit Card number Card Expiry Date and ATM PIN (or CVV2 and Date of birth for Credit Cards along with your mobile number and email id). Once the details are validated One time password will be sent to your email id and mobile no using this permanent password can be set. You can also reset your password while transacting click on Forgot password on the secure password page Authenticate your identity after entering your Credit/Debit Card number Card Expiry Date and ATM PIN (or CVV2 and Date of birth for Credit Cards along with your mobile number and email id). Once the details are validated One time password will be sent to your email id and mobile no using this permanent password can be set.\nClass: cards' metadata={'source': 'If I forget my VBV/MSC  password  how do I retrieve the same', 'row': 45}
# page_content='Question: While trying to register my card  I am getting the error message stating mobile no. mismatch What could be the reason\nAnswer: Please enter the mobile no you have updated in our system In case there is a change in the number Please contact our Customer Care Center and update the same.\nClass: accounts' metadata={'source': 'While trying to register my card  I am getting the error message stating mobile no. mismatch What could be the reason ', 'row': 46}
# page_content='Question: On which email id will I receive the OTP for Credit card registration or for password reset\nAnswer: If there are 2 email ids updated in our system OTP will be sent to both the email ids. However only one of them is required for validation during registration / password reset.\nClass: cards' metadata={'source': 'On which email id will I receive the OTP for Credit card registration or for password reset', 'row': 47}
# page_content="Question: While trying to register I am getting error message Card already enrolled  what should I do\nAnswer: Your card is already registered for Verified by Visa / MasterCard SecureCode you don't have to re-register your card. In case you don't remember your password please click on forgot password on the Netsafe login page or on the secure page while transacting and you can reset your password.\nClass: cards" metadata={'source': 'While trying to register I am getting error message Card already enrolled  what should I do', 'row': 48}
# page_content="Question: I don't remember my Verified by Visa / MasterCard Securecode login Id\nAnswer: You can use your Credit/Debit card number as your login id. The login id is required only to login to Netsafe you don't require the login id for doing online transactions.\nClass: cards" metadata={'source': "I don't remember my Verified by Visa / MasterCard Securecode login Id", 'row': 49}
# page_content='Question: Where do I find the CVV2\nAnswer: CVV2 is three digit number mentioned at reverse of your card.\nClass: accounts' metadata={'source': 'Where do I find the CVV2', 'row': 50}
# page_content='Question: I am unable to transact online as my card is de-registered status  how do I re-register my card\nAnswer: You have to login to NetSafe on the GS Bank website using your login id & Verified by Visa/ MasterCard SecureCode password. Once you login to Netsafe click on reregister cards  enter your date of birth and CVV2 and post that the card will be reregistered. You can now use the card for online transaction.\nClass: cards' metadata={'source': 'I am unable to transact online as my card is de-registered status  how do I re-register my card', 'row': 51}
# page_content='Question: Is there a fee to register for Verified by Visa / MasterCard Securecode\nAnswer: The service is free There is no additional charges for using the service.\nClass: accounts' metadata={'source': 'Is there a fee to register for Verified by Visa / MasterCard Securecode', 'row': 52}
# page_content='Question: What steps should I take to ensure that my VBV / MSC Password is strong and difficult to guess\nAnswer: Avoid using a password that is easy to guess also avoid using a password that you have already used elsewhere. Password should be something that is easy for you to remember but difficult for anyone else to guess. Never share your password with others. You may even choose to change your password periodically.It is your responsibility to protect your VBV / MSC Password.\nClass: accounts' metadata={'source': 'What steps should I take to ensure that my VBV / MSC Password is strong and difficult to guess', 'row': 53}
# page_content='Question: Can I set my Personal Assurance Message to be the same as my VBV / MSC Password\nAnswer: Your Personal Assurance Message and your VBV / MSC Password must not be the same to ensure your accounts.\nClass: accounts' metadata={'source': 'Can I set my Personal Assurance Message to be the same as my VBV / MSC Password', 'row': 54}
# page_content="Question: What happens if I try to make a purchase at a merchant that doesn't participate in the Verified by Visa / MasterCard Securecode service\nAnswer: You will not be prompted to enter your for Verified by Visa / MasterCard Securecode password on these websites.By shopping at websites participating Verified by Visa / MasterCard Securecode merchants you have the extra layer of accounts as the transactions are authenticated using your Verified by Visa / MasterCard Securecode password.\nClass: cards" metadata={'source': "What happens if I try to make a purchase at a merchant that doesn't participate in the Verified by Visa / MasterCard Securecode service", 'row': 55}
# page_content='Question: Can I get the benefit of Verified by Visa/ MasterCard SecureCode accounts at online stores that are not participating in the service\nAnswer: No. you can only get the benefits of Verified by Visa/ MasterCard SecureCode at the participating online stores. However a number of online stores have the service available to them. In the meantime if an online stores you trust is not yet participating\nClass: cards' metadata={'source': 'Can I get the benefit of Verified by Visa/ MasterCard SecureCode accounts at online stores that are not participating in the service', 'row': 56}
# page_content='Question: What accounts do I need to provide to obtain a Business loan\nAnswer: To obtain the loan there is absolutely no need to provide any accounts or collateral.\nClass: loans' metadata={'source': 'What accounts do I need to provide to obtain a Business loan', 'row': 57}
# page_content='Question: What are the benefits of having a Current/Saving Account for my Business loan\nAnswer: You get preferred Processing Fee priority processing and simpler documentation if you have a Current/Saving Account with GS Bank. This is taken into account at the time of disbursal of the loan. You can pay through Standing Instructions to debit your GS Bank Account with the EMI amount.\nClass: loans' metadata={'source': 'What are the benefits of having a Current/Saving Account for my Business loan', 'row': 58}
# page_content='Question: How long will it take for me to get a Business Loan\nAnswer: Once you submit your application form and supporting documents we shall give approval within 5 working days provided everything is in order. All loan approvals are at the sole discretion of the bank.\nClass: loans' metadata={'source': 'How long will it take for me to get a Business Loan', 'row': 59}
# page_content='Question: Can I repay the loan earlier for Business Loan\nAnswer: Yes you can choose to repay your loan anytime after 6 months of taking the loan and after you have paid 06 EMIs along with applicable foreclosure charges. Please note Loan can be foreclosed by issuing a Demand draft / cheque at the branch\nClass: loans' metadata={'source': 'Can I repay the loan earlier for Business Loan', 'row': 60}
# page_content='Question: How can I get my address changed in my loan account\nAnswer: In order to change your address in our records you may visit the nearest Retail Loan Service Center and submit the following documents: Request form for Address Change. Self Attested copy of your revised address proof along with the original address proof for validation. In case a bearer submits the request on your behalf a bearer authorisation along with KYC documents(self attested copy and original for validation) of the bearer i.e. Identity and Signature Proof like PAN Card Aadhar Card Driving License or Passport Copy will also need to be provided.\nClass: loans' metadata={'source': 'How can I get my address changed in my loan account', 'row': 61}
# page_content='Question: What will be done with the post dated cheques if I request to change the mode of repayment/ account for my loan\nAnswer: Post Dated Cheques(PDCs)/Security Cheques submitted towards loan repayment that have not been encashed will be defaced and retained by the Bank. In case you wish to have your old Post Dated Cheques(PDCs)/ Security Cheques to be returned to you kindly lodge a request at the Retail Loan Service Center or through PhoneBanking or write us an email at www.GS Bankbank.com/services within 45 days from the date of application of change in repayment instructions. In case we do not hear from you within the stipulated period the defaced cheques will be destroyed.\nClass: loans' metadata={'source': 'What will be done with the post dated cheques if I request to change the mode of repayment/ account for my loan', 'row': 62}
# page_content='Question: What are the charges I have to pay to change the mode of repayment/ account for my loan\nAnswer: A service charge of Rs.500 is applicable for changes in loan repayment instructions issued from non-GS Bank Account (ECS or PDC facility). A cheque/payorder/demand draft for Rs. 500 favouring GS Bank Ltd Loan Account No. it will be required along with the revised set of repayment instructions.\nClass: loans' metadata={'source': 'What are the charges I have to pay to change the mode of repayment/ account for my loan', 'row': 63}
# page_content='Question: How can I change the mode of repayment/ account for my loan\nAnswer: In the event that you wish to change the mode of repayment/bank account for your loan repayment you may visit the nearest the Retail Loan Service Center and submit your request with the revised account mandate/instructions. You can opt to repay through alternate repayment instructions as follows: 1) Standing Instructions: We offer the Standing Instructions (SI) facility whereby we can directly debit your GS Bank account for EMI amounts on due dates. Please submit the following at your nearest Retail Loan Service Center: Request form for swap of repayment instructions. 3 Security cheques favoring GS Bank Ltd Loan Account No. << >> each undated and filled with a value equal to the sum of 3 EMIs. SI mandate duly filled and verified by GS Bank. In case a bearer submits the request on your behalf a bearer authorisation along with KYC documents(self attested copy and original for validation) of the beareri.e. Identity and Signature Proof like PAN Card Aadhar Card Driving License or Passport Copy will also need to be provided. 2) Electronic Clearing Service (ECS): We offer the ECS facility whereby we can directly debit your non-GS Bank account for EMI amounts on due dates. Please submit the following at your nearest Retail Loan Service Center: Request form for swap of repayment instructions. Security cheques favoring GS Bank Ltd Loan Account No. << >>*** ECS mandate duly filled and verified by your banker. ACH(Automated Clearing House) Mandate. Swap Charges of Rs.500/- favouring GS Bank Ltd Loan Account No. << >> In case a bearer submits the request on your behalf a bearer authorisation along with KYC documents(self attested copy and original for validation) of the beareri.e. Identity and Signature Proof like PAN Card Aadhar Card Driving License or Passport Copy will also need to be provided. ***Security Cheques: You need to issue 1 security cheque for every 6 Equated Monthly Installments (EMI). The amount on each security undated cheque should be equal to the sum of 3 EMIs. For example if your EMI amount is Rs. 1000 and you have paid 18 EMIs for a 36 month loan tenure you need to submit 3 Security Cheques of Rs. 3000 each. 3) Post-dated Cheques (This mode is allowed only if the location is non ECS): Please submit the following documents at your nearest Retail Loan Service Center: Request form for swap of repayment instructions Revised post dated cheques in favour of GS Bank Ltd Loan Account No. << >> for the balance EMIs. ACH(Automated Clearing House) Mandate Swap Charges of Rs.500/- favouring GS Bank Ltd Loan Account No. << >> In case a bearer submits the request on your behalf a bearer authorisation along with KYC documents(self attested copy and original for validation) of the beareri.e. Identity and Signature Proof like PAN Card Aadhar Card Driving License or Passport Copy will also need to be provided. View more\nClass: loans' metadata={'source': 'How can I change the mode of repayment/ account for my loan', 'row': 64}
# page_content='Question: How do I obtain a Duplicate Repayment Schedule for my loan account\nAnswer: You may obtain a Duplicate Repayment Schedule for your loan account free of charge by registering for our NetBanking facility on www.GS Bankbank.com and download the repayment schedule for your linked loan account. Alternatively you may visit the nearest Retail Loan Service Center and submit the following documents Request form for Duplicate Repayment Schedule. Duplicate Repayment Schedule Charges of Rs.200/- favouring GS Bank Ltd Loan Account No. << >> In case a bearer submits the request on your behalf a bearer authorisation along with KYC documents(self attested copy and original for validation) of the bearer i.e. Identity and Signature Proof like PAN Card Aadhar Card Driving License or Passport Copy will also need to be provided\nClass: loans' metadata={'source': 'How do I obtain a Duplicate Repayment Schedule for my loan account', 'row': 65}
# page_content='Question: How much loan can I avail of Business Loan\nAnswer: You can avail of a loan from Rs 50000/- to Rs 5000000/- depending on your income repayment capacity and respective location product cap.\nClass: loans' metadata={'source': 'How much loan can I avail of Business Loan', 'row': 66}
# page_content='Question: How do I repay my Business Loan\nAnswer: You pay the loan in equal monthly instalments (EMIs). The loan will be paid through post-dated cheques. You can also pay through Electronic Clearing System (ECS ) or a standing instruction to debit your GS Bank account with the EMI amount\nClass: loans' metadata={'source': 'How do I repay my Business Loan', 'row': 67}
# page_content='Question: What are the loan tenure options for Business Loan\nAnswer: You can repay your loan over a period of 12 to 48 months\nClass: loans' metadata={'source': 'What are the loan tenure options for Business Loan', 'row': 68}
# page_content='Question: Do I need to pledge anything or give collateral to get a car loan\nAnswer: No there no need for any collateral. You will only need you to hypothecate the car in our name. An endorsement will have to be made in the Registration Certificate (RC) book of the vehicle. This will be cancelled after you repay the loan.\nClass: loans' metadata={'source': 'Do I need to pledge anything or give collateral to get a car loan', 'row': 69}
# page_content='Question: How long can the tenure of my loan be\nAnswer: Usually the tenure of an Auto Loan is 3 to 7 years. The tenure also depends on the type of car you wish to purchase. If it is a super premium car the tenure is restricted to 3 years only. In addition the higher your tenure is the lower your EMI will be but the total interest outflow is higher.\nClass: loans' metadata={'source': 'How long can the tenure of my loan be', 'row': 70}
# page_content='Question: What documents do I need to submit after the loan amount is disbursed\nAnswer: You can keep the original car documents registration certificate insurance policy and tax papers with you.\nClass: loans' metadata={'source': 'What documents do I need to submit after the loan amount is disbursed', 'row': 71}
# page_content='Question: What happens if the car meets with an accident\nAnswer: In the event of an accident the first step is to inform the insurance company. The company then sends a surveyor to assess the extent of damages to the car. Your claim is then processed and paid directly to us unless you have taken an NOC from the bank in which case the payment will be made by the insurance company in your favour. The bank normally gives you an NOC if you are regular in your payments. In case of a complete loss the bank will receive the payment directly from the insurance company.\nClass: loans' metadata={'source': 'What happens if the car meets with an accident', 'row': 72}
# page_content='Question: Can I get finance for insurance and registration\nAnswer: No. The ex-showroom price is considered which does not cover insurance and registration charges.\nClass: loans' metadata={'source': 'Can I get finance for insurance and registration', 'row': 73}
# page_content='Question: How much loan can I get\nAnswer: The amount of the loan you can get depends on: The cost of the vehicle The type of vehicle (standard/premium) The percentage of finance offered\nClass: loans' metadata={'source': 'How much loan can I get', 'row': 74}
# page_content='Question: Can I sell my car before I repay my loan\nAnswer: No you cannot sell your car unless you repay your loan. An NOC is required from the financier before you can sell your car.\nClass: loans' metadata={'source': 'Can I sell my car before I repay my loan', 'row': 75}
# page_content='Question: How much time will it take to change the mode of repayment/ account to repay my loan\nAnswer: It will take 25 working days to activate the revised instructions. In case your next instalment falls due prior to the 25 day period instructions already lodged with us will be presented for payment.\nClass: loans' metadata={'source': 'How much time will it take to change the mode of repayment/ account to repay my loan', 'row': 76}
# page_content='Question: What is De-pledge\nAnswer: Removal of a pledge from the security to regain the rights over the security is called de-pledge. *Conditions Apply\nClass: loans' metadata={'source': 'What is De-pledge', 'row': 77}
# page_content="Question: What is Guarantor\nAnswer: A Guarantor is a person who guarantees to pay for someone else's debt if he or she should default on a loan obligation.\nClass: loans" metadata={'source': 'What is Guarantor', 'row': 78}
# page_content='Question: What is Amortization\nAnswer: Amortization is paying off debts in regular instalments over a period of time.\nClass: loans' metadata={'source': 'What is Amortization', 'row': 79}
# page_content='Question: What is Pledge\nAnswer: A right over the security is created in favour of GS Bank. Hence shares cannot be transferred or sold by the customer or shareholder.\nClass: loans' metadata={'source': 'What is Pledge', 'row': 80}
# page_content="Question: What is RTGS\nAnswer: RTGS is the Real Time Gross Settlement which is used for the transfer of amounts of Rs. 100000 or more from one bank account to another bank account (any bank located anywhere in India if attached with an Internet system) at very minimal charges. The amount is credited into the beneficiary's account in real time. For amounts less than Rs. 100000 we use NEFT( National Electronic Fund Transfer).\nClass: loans" metadata={'source': 'What is RTGS', 'row': 81}
# page_content='Question: What is NEFT\nAnswer: The National Electronic Funds Transfer (NEFT) system is a nation-wide funds transfer system to facilitate transfer of funds from any bank branch to any other bank branch.\nClass: loans' metadata={'source': 'What is NEFT', 'row': 82}
# page_content='Question: What is SI\nAnswer: SI stands for Standing Instructions. It is one of the modes you can use to repay a loan wherein your GS Bank account is directly debited for the EMI amounts based on your specific instructions in the form of the Standing Instructions Mandate.\nClass: loans' metadata={'source': 'What is SI', 'row': 83}
# page_content="Question: What is CIBIL\nAnswer: CIBIL stands for Credit Information Bureau India Limited. CIBIL's aim is to fulfil the need of credit granting institutions for comprehensive credit information by collecting collating and disseminating credit information pertaining to both commercial and consumer borrowers to a closed user group of members. Banks Financial Institutions Non-Banking Financial Companies Housing Finance Companies and Credit Card Companies use CIBIL's services. Data sharing is based on the Principle of Reciprocity which means that only Members who have submitted all their credit data may access Credit Information Reports from CIBIL. The establishment of CIBIL is an effort made by the Government of India and the Reserve Bank of India to improve the functionality and stability of the Indian financial system by containing NPAs while improving credit grantors' portfolio quality. CIBIL provides a vital service which allows its Members to make informed objective and faster credit decisions. View more\nClass: loans" metadata={'source': 'What is CIBIL', 'row': 84}
# page_content='Question: Which documents should I carry at the time of visiting GS Bank\nAnswer: You need to carry an Agreement Number Self-attested Identification Proof containing your signature to avail of any information / deliverable along with a written request and produce the documents at the Customer Service Desk. If you want to change your address / contact details you need to submit an address change request along with a Self-attested copy of your revised address proof. The Request form for Address Change is available on the Form Centre of GS Bank website. View more\nClass: loans' metadata={'source': 'Which documents should I carry at the time of visiting GS Bank', 'row': 85}
# page_content='Question: Who can resolve my queries\nAnswer: For your queries related to Loans (other than home loans) please visit the nearest Retail Asset Branch. You can also write to us at www.GS Bankbank.com/services with the following verification details or contact your nearest PhoneBanking officer: Loan account number Name of applicant / loan favouring Date of birth of the applicant (as provided in loan application form) Correspondence address Loan amount EMI amount Mode of repayment (standing instruction / ECS / post date cheques) Bank name and account number from which the EMIs are collected Query / Complain View more\nClass: loans' metadata={'source': 'Who can resolve my queries', 'row': 86}
# ...
# page_content='Question: Can I use a GS Bank loan to finance home improvements on a property I do not own outright\nAnswer: Yes you can use a GS Bank loan to finance home improvements on a property you do not own outright but the process may vary depending on your ownership interest in the property. If you are a homeowner with existing equity in the property you may be eligible for a home equity loan or a home equity line of credit (HELOC) to finance home improvements. These loans allow you to borrow against the equity you have built in the property providing funds for renovations. If you are a tenant or do not have significant equity in the property you may still be eligible for personal loans or other types of financing to cover home improvements. However the terms and eligibility criteria may differ from those of home equity loans. Our loan specialists can review your ownership status and financial situation to determine the most suitable loan option for financing your home improvements.\nClass: loans' metadata={'source': 'Can I use a GS Bank loan to finance home improvements on a property I do not own outright', 'row': 1984}
# page_content='Question: Can I apply for a loan at GS Bank if I am currently unemployed\nAnswer: Yes you can apply for a loan at GS Bank if you are currently unemployed but your employment status may affect your loan eligibility and the terms offered to you. When evaluating your loan application we consider factors such as your income from other sources your credit history and your overall financial stability. While having stable employment and a steady income may increase your chances of loan approval it is not always a requirement. If you are unemployed you may still qualify for a loan if you have other sources of income such as investments retirement benefits or rental income. Providing documentation of these alternative income sources can strengthen your loan application. Our loan specialists can review your financial situation and provide guidance on available loan options based on your individual circumstances.\nClass: loans' metadata={'source': 'Can I apply for a loan at GS Bank if I am currently unemployed', 'row': 1985}
# page_content="Question: Can I apply for a loan at GS Bank if I am a student with limited income\nAnswer: Yes you can apply for a loan at GS Bank if you are a student with limited income but your eligibility may depend on various factors including your credit history employment status and ability to repay the loan. While having limited income as a student may pose challenges in qualifying for certain types of loans such as mortgages or auto loans there are loan options available specifically designed for students such as student loans or personal loans with cosigners. When applying for a loan as a student it's essential to consider your ability to repay the loan after graduation and to explore options such as income-based repayment plans or deferment options.Our loan specialists can provide information on available loan options for students and assist you in navigating the application process.\nClass: loans" metadata={'source': 'Can I apply for a loan at GS Bank if I am a student with limited income', 'row': 1986}
# page_content='Question: How does GS Bank calculate the maximum loan amount I can borrow\nAnswer: GS Bank calculates the maximum loan amount you can borrow based on various factors including your income creditworthiness debt-to-income ratio and the type of loan product you are applying for. For example mortgage lenders typically use a debt-to-income ratio to determine how much you can afford to borrow for a home purchase. This ratio compares your total monthly debt payments to your gross monthly income and helps lenders assess your ability to repay the loan. Similarly auto lenders may consider factors such as your credit score income stability and the value of the vehicle you are purchasing when determining the maximum loan amount. Our loan specialists can review your financial situation and provide guidance on the maximum loan amount available to you based on our lending criteria and the type of loan product you are interested in.\nClass: loans' metadata={'source': 'How does GS Bank calculate the maximum loan amount I can borrow', 'row': 1987}
# page_content='Question: Does GS Bank offer loan options for small businesses or startups\nAnswer: Yes GS Bank offers loan options for small businesses and startups to help them finance various business needs such as working capital equipment purchases or expansion projects. Small business loans may include term loans lines of credit or SBA (Small Business Administration) loans each with its own terms requirements and eligibility criteria. Startups may also be eligible for financing through business lines of credit equipment financing or other types of loans tailored to their needs. Our loan specialists can assess your business requirements and financial situation to recommend the most suitable loan options for your small business or startup. They can provide guidance on the application process required documentation and eligibility criteria for each type of loan product.\nClass: loans' metadata={'source': 'Does GS Bank offer loan options for small businesses or startups', 'row': 1988}
# page_content="Question: Can I use a GS Bank loan to finance the purchase of a rental property\nAnswer: Yes you can use a GS Bank loan to finance the purchase of a rental property subject to certain conditions and eligibility criteria. We offer mortgage loans specifically designed for investment properties including single-family homes multi-unit properties and vacation rentals. When applying for a loan to purchase a rental property lenders typically consider factors such as the property's rental income potential your financial stability and your experience as a landlord. You may need to provide documentation such as rental income history lease agreements and property management experience to support your loan application. Our loan specialists can provide information on available loan options for financing rental properties and guide you through the application process.\nClass: loans" metadata={'source': 'Can I use a GS Bank loan to finance the purchase of a rental property', 'row': 1989}
# page_content='Question: Can I apply for a loan at GS Bank if I have recently filed for bankruptcy\nAnswer: Yes you can apply for a loan at GS Bank if you have recently filed for bankruptcy but your eligibility and the terms offered to you may be affected by the bankruptcy filing. When evaluating your loan application we consider factors such as the type of bankruptcy filed the date of discharge and your current financial situation. While a recent bankruptcy may impact your credit score and ability to qualify for certain loan products it does not necessarily disqualify you from obtaining a loan. Providing explanations and documentation related to the bankruptcy filing along with demonstrating financial stability since then can strengthen your loan application. Our loan specialists can review your situation and provide guidance on available loan options based on your individual circumstances.\nClass: loans' metadata={'source': 'Can I apply for a loan at GS Bank if I have recently filed for bankruptcy', 'row': 1990}
# page_content='Question: Can I use a GS Bank loan to purchase a commercial property for my business\nAnswer: Yes you can use a GS Bank loan to purchase a commercial property for your business such as an office building retail space or warehouse. We offer commercial real estate loans specifically designed for business owners looking to purchase or refinance commercial properties. Commercial real estate loans may include options such as term loans commercial mortgages or SBA 504 loans each with its own terms requirements and eligibility criteria. These loans can provide funding for property acquisition construction renovations or expansion projects. Our loan specialists can assess your business needs and financial situation to recommend the most suitable commercial real estate loan options for your business. They can also provide guidance on the application process and required documentation.\nClass: loans' metadata={'source': 'Can I use a GS Bank loan to purchase a commercial property for my business', 'row': 1991}
# page_content="Question: Can I use a GS Bank loan to purchase a vehicle from a private seller\nAnswer: Yes you can use a GS Bank loan to purchase a vehicle from a private seller but the process may vary slightly from purchasing a vehicle from a dealership. When applying for an auto loan to finance a vehicle purchase from a private seller you may need to provide additional documentation such as the vehicle's title bill of sale and vehicle history report. The lender may also require an inspection or appraisal of the vehicle to assess its condition and value. Additionally the loan terms and eligibility criteria for purchasing a vehicle from a private seller may differ from those for purchasing from a dealership. Our loan specialists can provide guidance on the loan options available for purchasing a vehicle from a private seller and help you navigate the application process.\nClass: loans" metadata={'source': 'Can I use a GS Bank loan to purchase a vehicle from a private seller', 'row': 1992}
# page_content='Question: Can I use a GS Bank loan to finance home renovations or remodeling projects\nAnswer: Yes you can use a GS Bank home improvement loan or personal loan to finance home renovations or remodeling projects providing funding for expenses such as materials labor and contractor fees. Home improvement loans are specifically designed to help homeowners finance renovations or upgrades to their properties such as kitchen remodels bathroom renovations or landscaping projects. These loans may offer competitive interest rates and flexible repayment terms making them a convenient financing option for home improvement projects. Personal loans can also be used to fund home renovations offering flexibility in how the funds are used. These loans typically have fixed interest rates and predictable monthly payments allowing you to budget for your renovation expenses. Our loan specialists can provide information on available loan options for financing home renovations and assist you in selecting the best financing solution for your project.\nClass: loans' metadata={'source': 'Can I use a GS Bank loan to finance home renovations or remodeling projects', 'row': 1993}
# page_content='Question: Can I apply for a loan at GS Bank if I am a non-U.S. citizen\nAnswer: Yes non-U.S. citizens can apply for loans at GS Bank but eligibility requirements may vary depending on immigration status residency status and other factors. Non-U.S. citizens may need to provide additional documentation to support their loan applications such as a valid passport visa or other identification documents. Lenders may also consider factors such as visa expiration dates employment status and credit history when evaluating loan applications from non-U.S. citizens. Our loan specialists can review your individual situation and provide guidance on the loan options available to you based on your immigration status and financial profile. They can also assist with the application process and required documentation.\nClass: loans' metadata={'source': 'Can I apply for a loan at GS Bank if I am a non-U.S. citizen', 'row': 1994}
# page_content='Question: Can I use a GS Bank loan to refinance my existing mortgage\nAnswer: Yes you can use a GS Bank loan to refinance your existing mortgage to take advantage of better interest rates lower monthly payments or different loan terms. Mortgage refinancing involves replacing your current mortgage with a new loan under different terms. This can help you save money on interest costs shorten the loan term or switch from an adjustable-rate mortgage to a fixed-rate mortgage depending on your financial goals. Our mortgage specialists can assess your current mortgage terms and financial situation to determine whether refinancing is a suitable option for you. They can also provide information on available refinancing options and guide you through the application process.\nClass: loans' metadata={'source': 'Can I use a GS Bank loan to refinance my existing mortgage', 'row': 1995}
# page_content="Question: Can I use a GS Bank loan to purchase a vehicle from a private seller\nAnswer: Yes you can use a GS Bank loan to purchase a vehicle from a private seller but the process may vary slightly from purchasing a vehicle from a dealership. When applying for an auto loan to finance a vehicle purchase from a private seller you may need to provide additional documentation such as the vehicle's title bill of sale and vehicle history report. The lender may also require an inspection or appraisal of the vehicle to assess its condition and value. Additionally the loan terms and eligibility criteria for purchasing a vehicle from a private seller may differ from those for purchasing from a dealership. Our loan specialists can provide guidance on the loan options available for purchasing a vehicle from a private seller and help you navigate the application process.\nClass: loans" metadata={'source': 'Can I use a GS Bank loan to purchase a vehicle from a private seller', 'row': 1996}
# page_content='Question: Can I use a GS Bank loan to fund my dream of starting a small-scale sustainable farm\nAnswer: Absolutely! GS Bank offers flexible loan options that can be tailored to support your entrepreneurial ventures including starting a small-scale sustainable farm. Our loan specialists understand the unique needs of agricultural businesses and can assist you in structuring a loan that aligns with your vision for sustainable farming practices.\nClass: loans' metadata={'source': 'Can I use a GS Bank loan to fund my dream of starting a small-scale sustainable farm', 'row': 1997}
# page_content="Question: Can I apply for a loan at GS Bank to fund my passion project of converting an old warehouse into a community arts space\nAnswer: Certainly! GS Bank is committed to supporting projects that enrich communities and promote creativity. Whether you're converting an old warehouse into a community arts space a coworking hub or a cultural center our loan specialists can work with you to explore financing options that bring your vision to life. Let's collaborate to make your passion project a reality!\nClass: loans" metadata={'source': 'Can I apply for a loan at GS Bank to fund my passion project of converting an old warehouse into a community arts space', 'row': 1998}
# page_content="Question: Can I apply for a loan at GS Bank to invest in eco-friendly upgrades for my home such as solar panels or energy-efficient appliances\nAnswer: Absolutely! GS Bank is committed to supporting environmentally-conscious initiatives including home improvements that promote sustainability. Our loan specialists can help you explore financing options for eco-friendly upgrades to your home such as solar panel installations energy-efficient appliances or insulation upgrades. Let's work together to make your home more energy-efficient and environmentally friendly!\nClass: loans" metadata={'source': 'Can I apply for a loan at GS Bank to invest in eco-friendly upgrades for my home such as solar panels or energy-efficient appliances', 'row': 1999}

# %% [markdown]
# ##Prepare Data

# %%
# Initialize instructor embeddings using the Hugging Face model
instructor_embeddings = HuggingFaceInstructEmbeddings()

embedding = instructor_embeddings.embed_query("What type of credit cards do you offer")
# Out:
# .gitattributes:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/270 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/66.3k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.41k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# load INSTRUCTOR_Transformer
# max_seq_length  512

# %%
type(embedding)
# Out:
# list

# %%
len(embedding)
# Out:
# 768

# %%
embedding[:5] # first five elevents of the embedding vector
# Out:
# [-0.019814150407910347,
#  -0.0006104148342274129,
#  -0.005761954467743635,
#  -0.03236939758062363,
#  0.023019425570964813]

# %% [markdown]
# ## Vector store using FAISS and Q&A Chain

# %%
# Create a FAISS instance for vector database from 'data'
vectordb = FAISS.from_documents(documents = data, embedding = instructor_embeddings)

# %%
#save vector
#vectordb.save_local("FAISS_Q&A")

# %%
#load from local
#vectordb_s = FAISS.load_local("FAISS_Q&A", instructor_embeddings, allow_dangerous_deserialization = True)

# %%
# Create a retriever for querying the vector database
retriever = vectordb.as_retriever(score_threshold = 0.7)

rdocs = retriever.get_relevant_documents("How can I apply for a mortgage")
rdocs
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning:
#
# The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 0.3.0. Use invoke instead.
# [Document(page_content='Question: What is the process for applying for a mortgage loan\nAnswer: The process for applying for a mortgage loan involves several steps including prequalification loan application submission documentation verification property appraisal underwriting review loan approval and closing. Our mortgage specialists will guide you through each stage of the mortgage application process answer your questions and assist with required paperwork to ensure a smooth and efficient mortgage transaction.\nClass: loans', metadata={'source': 'What is the process for applying for a mortgage loan', 'row': 28}),
#  Document(page_content='Question: How do I apply for a loan at GS Bank\nAnswer: Applying for a loan with GS Bank is a straightforward process. You can start your application online through our secure website visit any of our branches or call our customer service team. The online application allows you to conveniently fill out your personal and financial information and submit any required documentation electronically. If you prefer in-person assistance our branch representatives are available to guide you through the application process. Once your application is submitted it will be reviewed and you will be contacted regarding the next steps which may include additional documentation or verification of information.\nClass: loans', metadata={'source': 'How do I apply for a loan at GS Bank', 'row': 5}),
#  Document(page_content='Question: What are the down payment requirements for mortgage loans\nAnswer: Down payment requirements for mortgage loans vary depending on factors such as loan type loan amount borrower qualifications and lender policies. Conventional mortgage loans typically require a down payment of 3% to 20% of the home purchase price while government-backed loans (e.g. FHA loans VA loans) may offer lower down payment options for eligible borrowers. Our mortgage specialists can provide guidance on down payment requirements and assistance programs available for homebuyers.\nClass: loans', metadata={'source': 'What are the down payment requirements for mortgage loans', 'row': 1817}),
#  Document(page_content='Question: Do you offer loan options for first-time homebuyers\nAnswer: Yes we offer loan options specifically tailored for first-time homebuyers including FHA loans VA loans and conventional loan programs with low down payment requirements and flexible eligibility criteria. Our mortgage specialists can help you explore available loan programs determine eligibility and guide you through the home buying process as a first-time homebuyer.\nClass: loans', metadata={'source': 'Do you offer loan options for first-time homebuyers', 'row': 1818})]

# %%
## Create a retriever for querying the vector database loaded from the saved vectordb
#retriever_2 = vectordb_s.as_retriever(score_threshold = 0.7)
#rdocs2 = retriever_2.get_relevant_documents("How can I apply for a mortgage")
#rdocs2

# %%
api_key = "AIzaSyAWZNsqlcXLcPqDEjS6_YU56RsAMM9IFBE"

llm = GooglePalm(google_api_key=api_key, temperature=0.7)

# %%
prompt_template = """Given the following context and a question, generate an answer based on this context only.
In the answer try to provide as much text as possible from "Answer" section in the source document context without making much changes.
If the answer is not found in the context, kindly state "I can only support you with bank related questions. How else can I help you?"

CONTEXT: {context}

QUESTION: {question}"""


PROMPT = PromptTemplate(
    template=prompt_template, input_variables=["context", "question"]
)
chain_type_kwargs = {"prompt": PROMPT}
from langchain.chains import RetrievalQA

chain = RetrievalQA.from_chain_type(llm = llm, chain_type = "stuff", retriever=retriever, input_key = "query", return_source_documents=True, chain_type_kwargs={"prompt": PROMPT})

# %% [markdown]
# ##Q&A Test

# %%
chain("Do you offer insurance products?")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning:
#
# The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
# {'query': 'Do you offer insurance products?',
#  'result': '\n Answer: At GS Bank we offer a range of insurance products tailored to meet various needs including life insurance health insurance home insurance auto insurance and specialty insurance such as travel insurance and pet insurance.\nClass: insurance',
#  'source_documents': [Document(page_content='Question: What insurance products do you offer\nAnswer: At GS Bank we offer a range of insurance products tailored to meet various needs including life insurance health insurance home insurance auto insurance and specialty insurance such as travel insurance and pet insurance.\nClass: insurance', metadata={'source': 'What insurance products do you offer', 'row': 2}),
#   Document(page_content="Question: Do you offer insurance products for small businesses or commercial enterprises\nAnswer: Yes we offer insurance products for small businesses and commercial enterprises including business owners insurance (BOP) commercial property insurance general liability insurance commercial auto insurance workers' compensation insurance professional liability insurance and cyber liability insurance. Our comprehensive insurance solutions help protect businesses against property damage liability claims employee injuries business interruptions and other risks inherent to commercial operations. Consult with our business insurance specialists to assess your coverage needs and customize insurance solutions tailored to your industry size and risk profile.\nClass: insurance", metadata={'source': 'Do you offer insurance products for small businesses or commercial enterprises', 'row': 1810}),
#   Document(page_content='Question: Do you offer insurance products for renters or tenants\nAnswer: Yes we offer insurance products for renters or tenants known as renters insurance or tenant insurance. Renters insurance provides coverage for personal belongings liability protection additional living expenses and medical payments to others in the event of covered perils such as theft fire or vandalism.\nClass: insurance', metadata={'source': 'Do you offer insurance products for renters or tenants', 'row': 1803}),
#   Document(page_content='Question: Do you offer any discounts for Home Insurance\nAnswer: Yes we do. The discounts available are: 24 hour security guard  5% Burglar Alarm  5% Both  15%\nClass: insurance', metadata={'source': 'Do you offer any discounts for Home Insurance', 'row': 873})]}

# %%
chain("Can I get a loan to buy a car")
# Out:
# {'query': 'Can I get a loan to buy a car',
#  'result': '\n Answer: Yes, we offer New Car Loans to purchase a car from any authorized car dealer in India.\nClass: loans',
#  'source_documents': [Document(page_content='Question: So how do I get the Loan against Car\nAnswer: To get the Loan against Car just fill the Online Application Form and our representative will get in touch with you shortly. Or you can also Call us or Visit our branch.\nClass: loans', metadata={'source': 'So how do I get the Loan against Car', 'row': 145}),
#   Document(page_content="Question: Which cars can be financed for New Car Loans\nAnswer: We finance most passenger cars and multi-utility vehicles manufactured by India's leading automobile companies.\nClass: loans", metadata={'source': 'Which cars can be financed for New Car Loans', 'row': 101}),
#   Document(page_content='Question: Which cars can be financed for Loan against Car\nAnswer: Any Hatchbacks and Sedans excluding some models that are out of production can be financed. To know more give us a call or visit a branch.\nClass: loans', metadata={'source': 'Which cars can be financed for Loan against Car', 'row': 148}),
#   Document(page_content="Question: Which cars can be financed for Pre-owned Car Loans\nAnswer: We finance most of passenger cars manufactured by India's leading automobile companies\nClass: loans", metadata={'source': 'Which cars can be financed for Pre-owned Car Loans', 'row': 127})]}

# %%
chain("Can I apply for a loan to spend two weeks in the maledives")
# Out:
# {'query': 'Can I apply for a loan to spend two weeks in the maledives',
#  'result': 'Yes you can apply for a personal loan to finance a vacation or travel expenses providing flexibility and convenience for funding leisure activities trips or vacations. Personal loans offer fixed-rate financing with predictable monthly payments allowing you to budget and plan for travel expenses without relying on credit cards or depleting savings. Consider factors such as loan amount interest rate and repayment terms when using a personal loan for travel purposes and ensure affordability and responsible borrowing practices.\nClass: loans',
#  'source_documents': [Document(page_content='Question: Can I use a personal loan to finance a vacation or travel expenses\nAnswer: Yes you can use a personal loan to finance a vacation or travel expenses providing flexibility and convenience for funding leisure activities trips or vacations. Personal loans offer fixed-rate financing with predictable monthly payments allowing you to budget and plan for travel expenses without relying on credit cards or depleting savings. Consider factors such as loan amount interest rate and repayment terms when using a personal loan for travel purposes and ensure affordability and responsible borrowing practices.\nClass: loans', metadata={'source': 'Can I use a personal loan to finance a vacation or travel expenses', 'row': 0}),
#   Document(page_content='Question: Can I use a GS Bank loan to purchase a second home or vacation property\nAnswer: Yes you can use a GS Bank loan to purchase a second home or vacation property subject to certain conditions and eligibility criteria. We offer mortgage loans specifically designed for second homes and vacation properties which may have different requirements and terms compared to primary residence mortgages. For example second home mortgages may require higher down payments and have slightly higher interest rates to reflect the increased risk associated with non-primary residences. Our loan specialists can provide information on available loan options for purchasing second homes or vacation properties and guide you through the application process.\nClass: loans', metadata={'source': 'Can I use a GS Bank loan to purchase a second home or vacation property', 'row': 1972}),
#   Document(page_content='Question: Can I be insured for a trip of any duration under the Travel Insurance policy\nAnswer: Yes our travel plans provide coverage for trips as short as 1  4 days.\nClass: insurance', metadata={'source': 'Can I be insured for a trip of any duration under the Travel Insurance policy', 'row': 1187}),
#   Document(page_content='Question: Can I apply for a loan at GS Bank if I am a non-U.S. citizen\nAnswer: Yes non-U.S. citizens can apply for loans at GS Bank but eligibility requirements may vary depending on immigration status residency status and other factors. Non-U.S. citizens may need to provide additional documentation to support their loan applications such as a valid passport visa or other identification documents. Lenders may also consider factors such as visa expiration dates employment status and credit history when evaluating loan applications from non-U.S. citizens. Our loan specialists can review your individual situation and provide guidance on the loan options available to you based on your immigration status and financial profile. They can also assist with the application process and required documentation.\nClass: loans', metadata={'source': 'Can I apply for a loan at GS Bank if I am a non-U.S. citizen', 'row': 1994})]}

# %%
chain("Can I apply for a loan if I am a student")
# Out:
# {'query': 'Can I apply for a loan if I am a student',
#  'result': '\nAnswer: I can only support you with bank related questions. How else can I help you?',
#  'source_documents': [Document(page_content="Question: Can I apply for a loan at GS Bank if I am a student with limited income\nAnswer: Yes you can apply for a loan at GS Bank if you are a student with limited income but your eligibility may depend on various factors including your credit history employment status and ability to repay the loan. While having limited income as a student may pose challenges in qualifying for certain types of loans such as mortgages or auto loans there are loan options available specifically designed for students such as student loans or personal loans with cosigners. When applying for a loan as a student it's essential to consider your ability to repay the loan after graduation and to explore options such as income-based repayment plans or deferment options.Our loan specialists can provide information on available loan options for students and assist you in navigating the application process.\nClass: loans", metadata={'source': 'Can I apply for a loan at GS Bank if I am a student with limited income', 'row': 1986}),
#   Document(page_content='Question: Can I apply for a loan at GS Bank if I have student loan debt\nAnswer: Yes you can apply for a loan at GS Bank even if you have existing student loan debt. However your student loan debt may affect your loan eligibility and borrowing capacity especially if it significantly impacts your debt-to-income ratio. When evaluating your loan application we consider your total debt obligations including student loans along with your income and credit history. Having student loan debt does not necessarily disqualify you from obtaining a loan but it may affect the terms and conditions of the loan. Our loan specialists can review your financial situation and provide guidance on how to manage your existing debt while applying for a new loan.\nClass: loans', metadata={'source': 'Can I apply for a loan at GS Bank if I have student loan debt', 'row': 1971}),
#   Document(page_content='Question: Can I apply for a loan if I am self-employed or have irregular income\nAnswer: Yes you can apply for a loan if you are self-employed or have irregular income although additional documentation and verification may be required to assess your income stability and repayment capacity. Self-employed individuals may need to provide tax returns profit and loss statements bank statements and other financial documents to verify income and qualify for a loan. Our loan specialists understand the unique challenges faced by self-employed borrowers and can assist with specialized loan solutions tailored to your financial situation.\nClass: loans', metadata={'source': 'Can I apply for a loan if I am self-employed or have irregular income', 'row': 18}),
#   Document(page_content='Question: How do I know if I am eligible for an education loan for foreign education\nAnswer: If you are an Indian resident/citizen have got admission for a job oriented professional / technical courses offered by reputed universities MBA MCA MS etc Degree / diploma courses like aeronautical shipping etc provided these are recognized by competent regulatory bodies in India/abroad for the purpose of employment in India / abroad.\nClass: loans', metadata={'source': 'How do I know if I am eligible for an education loan for foreign education', 'row': 228})]}

# %%
chain("How can I reset my pin for my credit card")
# Out:
# {'query': 'How can I reset my pin for my credit card',
#  'result': '\nAnswer: I can only support you with bank related questions. How else can I help you?',
#  'source_documents': [Document(page_content='Question: What should I do if I forget my GS Bank credit card PIN\nAnswer: If you forget your GS Bank credit card PIN you can reset it through our online banking portal or mobile app by navigating to the PIN management section. Alternatively you can contact our customer service team for assistance. For security purposes we may require identity verification before resetting your PIN.\nClass: cards', metadata={'source': 'What should I do if I forget my GS Bank credit card PIN', 'row': 1906}),
#   Document(page_content='Question: What if I forget my ATM PIN\nAnswer: Customer can reset ATM PIN by following the below steps: Login to Prepaid NetBanking using IPIN Select My Request ->Set ATM PIN -> Selects the Active Card (Radio Button) Answer the secret question. Mention DOB Card Expiry and submit Enter the new ATM PIN to be set and finally submit. You will then get an SMS / email alert on your registered mobile number / email address\nClass: cards', metadata={'source': 'What if I forget my ATM PIN', 'row': 1616}),
#   Document(page_content='Question: What is the procedure to follow if my Debit Card PIN is blocked\nAnswer: Please note that if you enter an incorrect PIN three times in the ATM your access gets blocked for security reasons. It gets activated after 24 hours. Kindly use your Debit / ATM Card at the ATM after 24 hours with the same PIN available with you. If your account still remains inaccessible please apply for new PIN. You can apply for regeneration of your ATM / Debit PIN in following ways: Fill-up the new PIN application form and submit it at any of our branches. On receipt of the form and successful verification we will process a new ATM PIN and send it to your mailing address as registered in our records. Submit a request at PhoneBanking after validation with your Telephone Identification Number (TIN). For every PIN Regeneration request charges of Rs. 50 + Service Tax + Educational Cess is applicable. For more details Contact Us View more\nClass: cards', metadata={'source': 'What is the procedure to follow if my Debit Card PIN is blocked', 'row': 1351}),
#   Document(page_content='Question: Reissuance of ATM/Debit Card PIN\nAnswer: For reissuance of your ATM / Debit PIN please choose any of the following modes: A. Through NetBanking - Click on Debit card. Select Pin Regeneration Select the card number. Click on continue Select the Reason for Regeneration Check the mailing address and confirm. Click on Terms and conditions and confirm B. Through Branch - Please download Application Form The Application Form should be duly filled and signed by all Account Holder/s Submit the duly filled Application Form at the nearest Branch On receipt of Form and successful verification the new ATM/Debit Card PIN will be sent to your mailing address To verify your mailing address in our records please log into NetBanking (Go to My Contact Details) C. Through PhoneBanking - Validate your Telephone Identification Number (TIN) View more\nClass: accounts', metadata={'source': 'Reissuance of ATM/Debit Card PIN', 'row': 715})]}
